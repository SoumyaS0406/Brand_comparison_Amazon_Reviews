# %% [markdown]
# # Script to Query Amazon API to get product details for reviews

# %%
import pandas as pd
from amazon.api import AmazonAPI
from amazon_scraper import AmazonScraper

# %%
AMAZON_ACCESS_KEY = 'AKIAJGU45UHYPC3GHN6A'
AMAZON_SECRET_KEY = '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'
AMAZON_ASSOC_TAG = 'vapatwa3-20'

# %%
reviews = pd.read_csv('reviews_Cell_Phones_and_Accessories.csv')

# %%
reviews.head(500)
# Out:
#            asin  overall                                         reviewText  \
# 0    011040047X      1.0  The case pictured is a soft violet color, but ...
# 1    0110400550      5.0  Saw this same case at a theme park store for 2...
# 2    0110400550      5.0  case fits perfectly and I always gets complime...
# 3    0110400550      5.0  Best phone case ever . Everywhere I go I get a...
# 4    0110400550      1.0  It may look cute. This case started off pretty...
# 5    0110400550      1.0  ITEM NOT SENT from Blue Top Company in Hong Ko...
# 6    0110400550      2.0  this is a cute case, I bought it for my wife b...
# 7    0110400550      3.0  it came in ok but there was a crack on the lef...
# 8    0110400550      3.0  The case is good, but the two pieces do not fi...
# 9    0110400550      4.0  I got this for my 14 year old sister.  She lov...
# 10   0110400550      4.0  The case is super cute, durable, and a convers...
# ...

# %% [markdown]
# ## Documentation : https://pypi.python.org/pypi/python-amazon-simple-product-api

# %%
amazon = AmazonAPI(AMAZON_ACCESS_KEY, AMAZON_SECRET_KEY, AMAZON_ASSOC_TAG)

# %%
product = amazon.lookup(ItemId='6073894996')

# %%
product.title
# Out:
# 'SANOXY High Output Dual USB Port Car Charger for Ipad, Samsung Galaxy, Iphone, Blackberry, Droid, Gps, and Other Tablets, Smart Phones and High Powered Devices'

# %%
p =product.api

# %%
product.model
# Out:
# 'SANOXY_DUALCAR'
