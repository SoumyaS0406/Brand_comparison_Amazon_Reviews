# %%
import pandas as pd
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
import gensim
from gensim import corpora
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
reviews = pd.read_csv('amaz.csv')

# %%
reviews.head()
# Out:
#                 Phone_Name               Date  Rating_Out_of_5  \
# 0  Samsung Galaxy S7 G930F    October 6, 2016              1.0
# 1  Samsung Galaxy S7 G930F    August 27, 2016              1.0
# 2  Samsung Galaxy S7 G930F  November 10, 2016              5.0
# 3  Samsung Galaxy S7 G930F   January 17, 2017              1.0
# 4  Samsung Galaxy S7 G930F       June 9, 2017              1.0
#
#                                         Review_Title  \
# 0                                Manufacturer Defect
# 1                                  False advertising
# 2  overall I'm pretty satisfied. I was afraid I w...
# 3  The phone stopped working after a few months a...
# 4       So it turned into a waste of time and a huge
#
#                                          Review_Text
# 0  The Galaxy S7 was wonderful while it worked. G...
# 1  The description on this phone said Dual Sim an...
# 2  I bought this on June 29, 2016. So far this ph...
# 3  The phone stopped working after a few months a...
# 4  Would rate 0 stars if i could doesn't work wit...

# %%
reviews[' Review_Text']
# Out:
# 0      The Galaxy S7 was wonderful while it worked. G...
# 1      The description on this phone said Dual Sim an...
# 2      I bought this on June 29, 2016. So far this ph...
# 3      The phone stopped working after a few months a...
# 4      Would rate 0 stars if i could doesn't work wit...
# 5      If there was a 0 star of rate that. Recueved t...
# 6      I am more of a Nexus / PIxel User! I bought th...
# 7      I WOULD ASSUME BECAUSE THIS PHONE MAY HAVE BEE...
# 8      I purchase this phone from the merchant Mobile...
# 9      So far so good. I have choosen Exynos version ...
# 10     I love this phone, a big upgrade from my samsu...
# 11     My phone froze for about 3 seconds then stoppe...
# 12     Absolutely in love with my Samsung galaxy s7. ...
# 13     Loved every minute of this phone. Going on 6 m...
# 14     The hardware of this phone is reaaaaaaally dec...
# 15     This phone has given me nothing but problems o...
# 16     Great comes brand new with original box and ac...
# 17     This phone is a beast! It performs perfectly. ...
# 18     This is hands down the best mobile I have ever...
# 19     Screen stopped working after only 7 months for...
# 20     lesson learned don't by factory unlocked. buy ...
# 21     This phone is GREAT, it's all I hoped it would...
# 22     Nice phone but I returned it because it could ...
# 23     I bought it and I found out that it is a chine...
# 24     So far so good!  We bought the phone for use i...
# 25     Came ready to use out of the box! I didn't hav...
# 26     The phone came in perfect condition. It came w...
# 27     This phone is excellent and the camera is amaz...
# 28     Are you F***** serious right now? I paid 540$ ...
# 29     Great device, really solid construction, perfe...
#                              ...
# 610    I gave it back because I was wrong to make the...
# 611    Everything in this phone from the processor, s...
# 612    Hey just to let u know, when i first received ...
# 613    the Phone loose the signal y try with another ...
# 614               its not what they show in the pictures
# 615                                                 None
# 616                         Great buy. I'm using it now.
# 617                                     Great smartphone
# 618                                      excellent phone
# 619    Phone got heat up very quick. I have to turn o...
# 620                                       It's excellent
# 621    Just got it & it seems good, lighter then I ha...
# 622                                  As promised. Thanks
# 623    All was ok except for the plug that it is made...
# 624    great phone, made me want to throw my iphone i...
# 625                                 It's very functional
# 626                                        That is nice.
# 627                                           Best phone
# 628    This is not an unlocked international version!...
# 629    I did not get any item just the Samsung Galaxy...
# 630               Unfortunately,  I got a used device...
# 631    i'm sorry but the phone fell out of my hand (n...
# 632    The product arrived in perfect condition but i...
# 633                                  It came whith flaws
# 634    I having problems with this product , after 2 ...
# 635                 got it on time.item is as described.
# 636    I had T-Mobile service on an iPhone 5S and bou...
# 637    I have yet to actually use the phone yet becau...
# 638    I've had this phone for almost 3 months and it...
# 639    Software crashed five days after my replacemen...
# Name:  Review_Text, Length: 640, dtype: object

# %%
rvs_lst = list(reviews[' Review_Text'])

# %%
stop = set(stopwords.words('english'))
exclude = set(string.punctuation)

# %%
lemma = WordNetLemmatizer()

# %%
def clean(doc):
    stop_free = " ".join([i for i in doc.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

# %%
doc_clean = [clean(doc).split() for doc in rvs_lst]

# %% [markdown]
# # Creating the term dictionary of our courpus, where every unique term is assigned an index.

# %%
dictionary = corpora.Dictionary(doc_clean)

# %% [markdown]
# # Converting list of documents (corpus) into Document Term Matrix using dictionary prepared above.

# %%
doc_term_matrix = [dictionary.doc2bow(doc) for doc in doc_clean]

# %%
Lda = gensim.models.ldamodel.LdaModel

# %%
ldamodel = Lda(doc_term_matrix, num_topics=10, id2word = dictionary, passes=50)

# %%
print(ldamodel.print_topics(num_topics=3, num_words=10)[2])
# Out:
# (7, '0.039*"perfect" + 0.023*"phone" + 0.016*"excelente" + 0.014*"month" + 0.010*"working" + 0.009*"stopped" + 0.009*"shipping" + 0.009*"using" + 0.008*"fast" + 0.008*"it"')

# %%
doc_term_matrix
# Out:
# [[(0, 2),
#   (1, 1),
#   (2, 1),
#   (3, 1),
#   (4, 2),
#   (5, 1),
#   (6, 1),
#   (7, 1),
#   (8, 1),
#   (9, 3),
#   (10, 1),
#   (11, 1),
#   (12, 1),
#   (13, 1),
#   (14, 1),
#   (15, 1),
#   (16, 2),
#   (17, 1),
#   (18, 1),
#   (19, 1),
#   (20, 1),
#   (21, 2),
#   (22, 1),
#   (23, 1),
#   (24, 1),
#   (25, 1),
#   (26, 1),
#   (27, 1),
#   (28, 1),
#   (29, 1),
#   (30, 1),
#   (31, 1),
#   (32, 1),
#   (33, 1),
#   (34, 2),
#   (35, 2),
#   (36, 1),
#   (37, 1),
#   (38, 2),
#   (39, 1),
#   (40, 1),
#   (41, 1),
#   (42, 1),
#   (43, 1),
#   (44, 1),
#   (45, 2),
#   (46, 1),
#   (47, 1),
#   (48, 1),
#   (49, 1),
#   (50, 1),
#   (51, 1),
#   (52, 1),
#   (53, 1),
#   (54, 1),
#   (55, 1),
#   (56, 1),
#   (57, 1),
#   (58, 1),
#   (59, 1),
#   (60, 1),
#   (61, 4),
#   (62, 1),
#   (63, 1),
#   (64, 1),
#   (65, 1),
#   (66, 1),
#   (67, 1),
#   (68, 2),
#   (69, 1),
#   (70, 1),
#   (71, 1),
#   (72, 1),
#   (73, 1),
#   (74, 2),
#   (75, 1),
#   (76, 1),
#   (77, 5),
#   (78, 1),
#   (79, 4),
#   (80, 1),
#   (81, 1),
#   (82, 1),
#   (83, 1),
#   (84, 1),
#   (85, 1),
#   (86, 1),
#   (87, 1),
#   (88, 1),
#   (89, 1),
#   (90, 1),
#   (91, 1),
#   (92, 1),
#   (93, 1),
#   (94, 1),
#   (95, 1),
#   (96, 1),
#   (97, 1),
#   (98, 1),
#   (99, 1),
#   (100, 1),
#   (101, 1),
#   (102, 1)],
#  [(53, 1),
#   (58, 1),
#   (61, 3),
#   (98, 1),
#   (103, 1),
#   (104, 1),
#   (105, 1),
#   (106, 2),
#   (107, 1),
#   (108, 1),
#   (109, 1),
#   (110, 1),
#   (111, 1),
#   (112, 1),
#   (113, 4),
#   (114, 1),
#   (115, 1),
#   (116, 1),
#   (117, 1)],
#  [(2, 1),
#   (35, 1),
#   (41, 2),
#   (58, 1),
#   (61, 1),
#   (84, 1),
#   (118, 1),
#   (119, 1),
#   (120, 1),
#   (121, 1),
#   (122, 1),
#   (123, 1),
#   (124, 1),
#   (125, 1),
#   (126, 1),
#   (127, 1),
#   (128, 1),
#   (129, 1),
#   (130, 1),
#   (131, 1),
#   (132, 2),
#   (133, 1),
#   (134, 2),
#   (135, 1),
#   (136, 1),
#   (137, 1)],
#  [(3, 1),
#   (54, 1),
#   (61, 1),
#   (127, 1),
#   (138, 1),
#   (139, 1),
#   (140, 1),
#   (141, 1),
#   (142, 1),
#   (143, 1),
#   (144, 1),
#   (145, 1),
#   (146, 1),
#   (147, 1),
#   (148, 1),
#   (149, 1)],
#  [(135, 1),
#   (137, 1),
#   (150, 1),
#   (151, 1),
#   (152, 1),
#   (153, 1),
#   (154, 1),
#   (155, 1),
#   (156, 1),
#   (157, 1),
#   (158, 1),
#   (159, 1),
#   (160, 1),
#   (161, 1),
#   (162, 1),
#   (163, 1),
#   (164, 1),
#   (165, 1)],
#  [(3, 1),
#   (8, 1),
#   (19, 1),
#   (28, 1),
#   (53, 1),
#   (59, 1),
#   (61, 3),
#   (74, 4),
#   (115, 1),
#   (116, 1),
#   (124, 1),
#   (150, 1),
#   (158, 1),
#   (161, 1),
#   (166, 1),
#   (167, 1),
#   (168, 1),
#   (169, 1),
#   (170, 1),
#   (171, 1),
#   (172, 1),
#   (173, 1),
#   (174, 1),
#   (175, 1),
#   (176, 1),
#   (177, 1),
#   (178, 1),
#   (179, 1),
#   (180, 1),
#   (181, 1),
#   (182, 1),
#   (183, 1),
#   (184, 5),
#   (185, 1),
#   (186, 1),
#   (187, 1),
#   (188, 1),
#   (189, 1),
#   (190, 1),
#   (191, 1),
#   (192, 1),
#   (193, 1),
#   (194, 1),
#   (195, 1),
#   (196, 1),
#   (197, 2),
#   (198, 1),
#   (199, 1),
#   (200, 1),
#   (201, 1),
#   (202, 1),
#   (203, 1),
#   (204, 1),
#   (205, 1),
#   (206, 2),
#   (207, 2),
#   (208, 1),
#   (209, 1),
#   (210, 1),
#   (211, 1),
#   (212, 1),
#   (213, 2),
#   (214, 1),
#   (215, 1)],
#  [(28, 2),
#   (45, 1),
#   (55, 1),
#   (58, 1),
#   (61, 5),
#   (75, 5),
#   (122, 4),
#   (124, 1),
#   (137, 2),
#   (139, 1),
#   (152, 2),
#   (168, 1),
#   (169, 1),
#   (216, 1),
#   (217, 1),
#   (218, 1),
#   (219, 1),
#   (220, 1),
#   (221, 1),
#   (222, 2),
#   (223, 1),
#   (224, 1),
#   (225, 1),
#   (226, 1),
#   (227, 1),
#   (228, 1),
#   (229, 1),
#   (230, 1),
#   (231, 1),
#   (232, 1),
#   (233, 2),
#   (234, 2),
#   (235, 2),
#   (236, 1),
#   (237, 1),
#   (238, 2),
#   (239, 1),
#   (240, 1),
#   (241, 3),
#   (242, 1),
#   (243, 2),
#   (244, 1),
#   (245, 1),
#   (246, 3),
#   (247, 1),
#   (248, 1),
#   (249, 1),
#   (250, 1),
#   (251, 1),
#   (252, 1),
#   (253, 1),
#   (254, 1),
#   (255, 1),
#   (256, 1),
#   (257, 1),
#   (258, 1),
#   (259, 1),
#   (260, 1),
#   (261, 1)],
#  [(21, 2),
#   (27, 1),
#   (38, 1),
#   (45, 1),
#   (48, 2),
#   (61, 4),
#   (74, 1),
#   (77, 1),
#   (132, 1),
#   (137, 1),
#   (143, 1),
#   (162, 1),
#   (192, 1),
#   (261, 1),
#   (262, 1),
#   (263, 1),
#   (264, 1),
#   (265, 1),
#   (266, 1),
#   (267, 1),
#   (268, 1),
#   (269, 1),
#   (270, 1),
#   (271, 1),
#   (272, 1),
#   (273, 2),
#   (274, 1),
#   (275, 1),
#   (276, 1),
#   (277, 1),
#   (278, 1),
#   (279, 2),
#   (280, 1),
#   (281, 1)],
#  [(3, 1),
#   (8, 1),
#   (44, 1),
#   (61, 2),
#   (174, 1),
#   (188, 1),
#   (282, 1),
#   (283, 1),
#   (284, 1),
#   (285, 1),
#   (286, 1),
#   (287, 1),
#   (288, 1),
#   (289, 1),
#   (290, 1),
#   (291, 1),
#   (292, 2)],
#  [(8, 1),
#   (35, 1),
#   (44, 1),
#   (61, 2),
#   (74, 1),
#   (77, 1),
#   (79, 1),
#   (95, 1),
#   (126, 1),
#   (132, 1),
#   (149, 1),
#   (165, 1),
#   (200, 1),
#   (211, 1),
#   (287, 1),
#   (293, 1),
#   (294, 1),
#   (295, 1),
#   (296, 1),
#   (297, 1),
#   (298, 1),
#   (299, 1),
#   (300, 1),
#   (301, 1),
#   (302, 2),
#   (303, 1),
#   (304, 1),
#   (305, 1),
#   (306, 2),
#   (307, 1),
#   (308, 1),
#   (309, 1),
#   (310, 1),
#   (311, 1),
#   (312, 1),
#   (313, 1),
#   (314, 1),
#   (315, 1),
#   (316, 1),
#   (317, 1),
#   (318, 1),
#   (319, 1),
#   (320, 1),
#   (321, 1),
#   (322, 1),
#   (323, 1)],
#  [(61, 1),
#   (75, 1),
#   (269, 1),
#   (289, 1),
#   (302, 1),
#   (312, 1),
#   (324, 1),
#   (325, 1),
#   (326, 1),
#   (327, 1),
#   (328, 1),
#   (329, 1),
#   (330, 1),
#   (331, 1),
#   (332, 1),
#   (333, 1)],
#  [(11, 1),
#   (28, 1),
#   (32, 1),
#   (45, 2),
#   (55, 1),
#   (56, 1),
#   (61, 1),
#   (79, 3),
#   (102, 1),
#   (112, 2),
#   (116, 2),
#   (132, 1),
#   (145, 2),
#   (149, 2),
#   (172, 1),
#   (176, 1),
#   (198, 1),
#   (200, 1),
#   (272, 1),
#   (277, 2),
#   (288, 1),
#   (334, 1),
#   (335, 1),
#   (336, 1),
#   (337, 1),
#   (338, 1),
#   (339, 1),
#   (340, 2),
#   (341, 1),
#   (342, 1),
#   (343, 1),
#   (344, 1),
#   (345, 1),
#   (346, 1),
#   (347, 1),
#   (348, 2),
#   (349, 1),
#   (350, 1),
#   (351, 1),
#   (352, 1),
#   (353, 1),
#   (354, 1),
#   (355, 1),
#   (356, 1),
#   (357, 2),
#   (358, 1),
#   (359, 2)],
#  [(0, 2),
#   (34, 1),
#   (35, 1),
#   (58, 1),
#   (61, 5),
#   (74, 1),
#   (75, 2),
#   (81, 1),
#   (113, 1),
#   (131, 1),
#   (163, 1),
#   (175, 3),
#   (266, 1),
#   (311, 2),
#   (328, 1),
#   (360, 1),
#   (361, 1),
#   (362, 1),
#   (363, 1),
#   (364, 1),
#   (365, 1),
#   (366, 1),
#   (367, 1),
#   (368, 1),
#   (369, 1),
#   (370, 1),
#   (371, 3),
#   (372, 1),
#   (373, 1),
#   (374, 1),
#   (375, 1),
#   (376, 1),
#   (377, 1),
#   (378, 2),
#   (379, 1),
#   (380, 1),
#   (381, 1),
#   (382, 1)],
#  [(5, 1),
#   (54, 1),
#   (58, 1),
#   (61, 1),
#   (163, 1),
#   (190, 1),
#   (216, 1),
#   (339, 1),
#   (383, 1),
#   (384, 1),
#   (385, 1),
#   (386, 1),
#   (387, 1),
#   (388, 1),
#   (389, 1),
#   (390, 1),
#   (391, 1)],
#  [(9, 1),
#   (20, 1),
#   (37, 3),
#   (45, 1),
#   (61, 3),
#   (66, 1),
#   (75, 1),
#   (77, 1),
#   (78, 2),
#   (84, 1),
#   (85, 1),
#   (131, 1),
#   (174, 1),
#   (222, 2),
#   (237, 1),
#   (243, 1),
#   (306, 1),
#   (310, 1),
#   (311, 2),
#   (318, 1),
#   (354, 1),
#   (392, 1),
#   (393, 1),
#   (394, 1),
#   (395, 1),
#   (396, 1),
#   (397, 1),
#   (398, 1),
#   (399, 1),
#   (400, 3),
#   (401, 1),
#   (402, 1),
#   (403, 1),
#   (404, 1),
#   (405, 1),
#   (406, 1),
#   (407, 1),
#   (408, 1),
#   (409, 1),
#   (410, 1),
#   (411, 1),
#   (412, 1),
#   (413, 1),
#   (414, 1),
#   (415, 1),
#   (416, 1),
#   (417, 1),
#   (418, 1),
#   (419, 1)],
#  [(45, 1),
#   (53, 1),
#   (56, 1),
#   (61, 1),
#   (74, 1),
#   (102, 1),
#   (127, 1),
#   (132, 2),
#   (287, 1),
#   (318, 1),
#   (340, 1),
#   (357, 1),
#   (372, 1),
#   (420, 1),
#   (421, 1),
#   (422, 1),
#   (423, 1),
#   (424, 1),
#   (425, 1),
#   (426, 1),
#   (427, 1),
#   (428, 1),
#   (429, 1),
#   (430, 1),
#   (431, 1),
#   (432, 1)],
#  [(8, 1), (38, 1), (269, 1), (282, 1), (287, 1), (433, 1), (434, 1)],
#  [(17, 1),
#   (25, 1),
#   (61, 1),
#   (77, 1),
#   (161, 1),
#   (213, 1),
#   (259, 1),
#   (435, 1),
#   (436, 1),
#   (437, 1),
#   (438, 1),
#   (439, 1),
#   (440, 1),
#   (441, 1),
#   (442, 1),
#   (443, 1),
#   (444, 1),
#   (445, 1),
#   (446, 1),
#   (447, 1),
#   (448, 1)],
#  [(10, 1),
#   (99, 1),
#   (137, 1),
#   (185, 1),
#   (220, 1),
#   (223, 1),
#   (286, 1),
#   (369, 1),
#   (390, 1),
#   (415, 1),
#   (436, 2),
#   (449, 1),
#   (450, 1),
#   (451, 1),
#   (452, 1),
#   (453, 2),
#   (454, 1),
#   (455, 1),
#   (456, 1),
#   (457, 1),
#   (458, 1),
#   (459, 1),
#   (460, 1),
#   (461, 1),
#   (462, 1),
#   (463, 1)],
#  [(54, 1),
#   (77, 1),
#   (145, 1),
#   (149, 1),
#   (199, 1),
#   (464, 1),
#   (465, 1),
#   (466, 1),
#   (467, 1),
#   (468, 1),
#   (469, 1)],
#  [(322, 1), (467, 1), (470, 1), (471, 1), (472, 1), (473, 1)],
#  [(28, 1),
#   (35, 1),
#   (38, 2),
#   (61, 1),
#   (75, 1),
#   (127, 1),
#   (132, 1),
#   (137, 2),
#   (161, 1),
#   (307, 1),
#   (332, 1),
#   (393, 1),
#   (474, 1),
#   (475, 1),
#   (476, 1),
#   (477, 1),
#   (478, 1),
#   (479, 1),
#   (480, 1),
#   (481, 1),
#   (482, 1),
#   (483, 1),
#   (484, 1),
#   (485, 1),
#   (486, 1),
#   (487, 2),
#   (488, 1),
#   (489, 1),
#   (490, 2),
#   (491, 1)],
#  [(61, 1),
#   (152, 1),
#   (207, 1),
#   (333, 1),
#   (481, 1),
#   (492, 1),
#   (493, 1),
#   (494, 1),
#   (495, 1),
#   (496, 2),
#   (497, 1)],
#  [(33, 1),
#   (45, 1),
#   (61, 1),
#   (75, 2),
#   (95, 3),
#   (116, 1),
#   (122, 1),
#   (177, 1),
#   (184, 1),
#   (222, 1),
#   (248, 1),
#   (269, 1),
#   (498, 1),
#   (499, 2),
#   (500, 1),
#   (501, 1),
#   (502, 1)],
#  [(11, 1),
#   (43, 1),
#   (61, 2),
#   (122, 2),
#   (126, 1),
#   (165, 1),
#   (226, 1),
#   (287, 1),
#   (306, 1),
#   (325, 2),
#   (333, 1),
#   (483, 1),
#   (503, 1),
#   (504, 2),
#   (505, 1),
#   (506, 1),
#   (507, 1),
#   (508, 2),
#   (509, 1),
#   (510, 1),
#   (511, 1)],
#  [(8, 1),
#   (32, 1),
#   (38, 1),
#   (74, 1),
#   (75, 1),
#   (113, 1),
#   (174, 1),
#   (277, 1),
#   (292, 1),
#   (301, 1),
#   (306, 1),
#   (316, 1),
#   (333, 2),
#   (450, 1),
#   (512, 1),
#   (513, 1),
#   (514, 1),
#   (515, 1),
#   (516, 1),
#   (517, 1),
#   (518, 1)],
#  [(44, 1),
#   (61, 2),
#   (95, 1),
#   (174, 2),
#   (329, 1),
#   (397, 1),
#   (519, 1),
#   (520, 1),
#   (521, 1),
#   (522, 1)],
#  [(2, 1), (10, 1), (61, 1), (523, 1)],
#  [(0, 1),
#   (3, 1),
#   (8, 1),
#   (27, 1),
#   (61, 2),
#   (92, 1),
#   (176, 1),
#   (199, 1),
#   (212, 1),
#   (213, 1),
#   (282, 1),
#   (287, 1),
#   (289, 1),
#   (295, 1),
#   (369, 1),
#   (428, 2),
#   (434, 1),
#   (524, 1),
#   (525, 1),
#   (526, 2),
#   (527, 1),
#   (528, 2),
#   (529, 1),
#   (530, 1),
#   (531, 1),
#   (532, 1),
#   (533, 1),
#   (534, 1),
#   (535, 1),
#   (536, 1)],
#  [(5, 2),
#   (10, 1),
#   (27, 1),
#   (38, 2),
#   (50, 1),
#   (75, 1),
#   (83, 1),
#   (137, 1),
#   (143, 1),
#   (206, 1),
#   (211, 1),
#   (222, 1),
#   (226, 1),
#   (233, 1),
#   (238, 1),
#   (257, 1),
#   (311, 1),
#   (318, 3),
#   (329, 1),
#   (374, 2),
#   (378, 1),
#   (389, 1),
#   (406, 1),
#   (412, 1),
#   (453, 1),
#   (454, 2),
#   (502, 1),
#   (506, 1),
#   (537, 1),
#   (538, 1),
#   (539, 1),
#   (540, 2),
#   (541, 1),
#   (542, 1),
#   (543, 1),
#   (544, 1),
#   (545, 1),
#   (546, 1),
#   (547, 1),
#   (548, 1),
#   (549, 1),
#   (550, 1),
#   (551, 1),
#   (552, 1),
#   (553, 1),
#   (554, 1),
#   (555, 1),
#   (556, 1),
#   (557, 1),
#   (558, 1),
#   (559, 1),
#   (560, 3)],
#  [(35, 1),
#   (44, 1),
#   (61, 4),
#   (139, 1),
#   (141, 1),
#   (146, 1),
#   (168, 1),
#   (215, 1),
#   (233, 2),
#   (277, 1),
#   (297, 1),
#   (373, 1),
#   (438, 1),
#   (449, 1),
#   (454, 1),
#   (467, 1),
#   (561, 1),
#   (562, 1),
#   (563, 1),
#   (564, 1),
#   (565, 1),
#   (566, 1)],
#  [(59, 1),
#   (75, 1),
#   (139, 1),
#   (165, 1),
#   (185, 1),
#   (226, 1),
#   (567, 1),
#   (568, 1),
#   (569, 1),
#   (570, 1),
#   (571, 1),
#   (572, 1),
#   (573, 1)],
#  [(34, 1),
#   (38, 1),
#   (44, 1),
#   (54, 1),
#   (61, 7),
#   (74, 1),
#   (95, 1),
#   (122, 1),
#   (132, 1),
#   (142, 1),
#   (151, 1),
#   (214, 1),
#   (228, 1),
#   (322, 2),
#   (333, 1),
#   (424, 1),
#   (466, 1),
#   (489, 1),
#   (500, 1),
#   (565, 1),
#   (574, 1),
#   (575, 1),
#   (576, 1),
#   (577, 1),
#   (578, 1),
#   (579, 1),
#   (580, 1),
#   (581, 1),
#   (582, 1),
#   (583, 1),
#   (584, 1),
#   (585, 1),
#   (586, 1),
#   (587, 1)],
#  [(27, 2),
#   (61, 3),
#   (102, 2),
#   (163, 1),
#   (272, 1),
#   (413, 1),
#   (588, 1),
#   (589, 1),
#   (590, 1),
#   (591, 1)],
#  [(132, 1), (306, 1), (592, 1), (593, 1), (594, 1)],
#  [(3, 1),
#   (61, 2),
#   (79, 1),
#   (103, 1),
#   (118, 1),
#   (173, 2),
#   (272, 1),
#   (434, 1),
#   (486, 1),
#   (595, 1),
#   (596, 1),
#   (597, 1),
#   (598, 1),
#   (599, 1),
#   (600, 1),
#   (601, 1),
#   (602, 1),
#   (603, 1),
#   (604, 1),
#   (605, 1),
#   (606, 1)],
#  [(22, 1),
#   (113, 1),
#   (132, 1),
#   (168, 2),
#   (174, 1),
#   (175, 1),
#   (215, 1),
#   (258, 1),
#   (322, 1),
#   (329, 1),
#   (412, 1),
#   (467, 1),
#   (477, 1),
#   (519, 1),
#   (523, 1),
#   (560, 1),
#   (607, 1),
#   (608, 1),
#   (609, 1),
#   (610, 1),
#   (611, 1),
#   (612, 1),
#   (613, 1),
#   (614, 1),
#   (615, 1),
#   (616, 1),
#   (617, 1)],
#  [(45, 1),
#   (56, 1),
#   (61, 4),
#   (113, 1),
#   (122, 1),
#   (126, 1),
#   (151, 1),
#   (162, 1),
#   (167, 1),
#   (175, 1),
#   (195, 1),
#   (230, 1),
#   (282, 1),
#   (287, 1),
#   (306, 1),
#   (328, 1),
#   (367, 1),
#   (479, 1),
#   (483, 1),
#   (489, 1),
#   (507, 1),
#   (577, 1),
#   (618, 1),
#   (619, 1),
#   (620, 1),
#   (621, 1),
#   (622, 1),
#   (623, 1),
#   (624, 1),
#   (625, 1),
#   (626, 1)],
#  [(5, 1), (47, 1), (306, 1), (627, 1)],
#  [(61, 1), (628, 1)],
#  [(48, 1), (77, 1), (598, 1), (629, 1)],
#  [(61, 1),
#   (74, 1),
#   (126, 1),
#   (162, 1),
#   (287, 1),
#   (307, 1),
#   (328, 1),
#   (478, 1),
#   (630, 1),
#   (631, 1),
#   (632, 1),
#   (633, 1),
#   (634, 1),
#   (635, 1)],
#  [(61, 1), (165, 1), (209, 1), (233, 1), (259, 1)],
#  [(28, 1), (627, 1), (636, 1)],
#  [(10, 1),
#   (34, 1),
#   (61, 1),
#   (78, 1),
#   (306, 1),
#   (316, 1),
#   (328, 1),
#   (494, 1),
#   (637, 1)],
#  [(11, 1),
#   (61, 2),
#   (78, 1),
#   (103, 1),
#   (104, 1),
#   (113, 1),
#   (122, 1),
#   (132, 2),
#   (163, 1),
#   (165, 1),
#   (233, 1),
#   (332, 1),
#   (390, 1),
#   (427, 1),
#   (459, 1),
#   (507, 1),
#   (523, 1),
#   (617, 1),
#   (635, 1),
#   (638, 1),
#   (639, 1),
#   (640, 1),
#   (641, 1),
#   (642, 2),
#   (643, 1),
#   (644, 1),
#   (645, 1),
#   (646, 1),
#   (647, 1),
#   (648, 1),
#   (649, 1),
#   (650, 1),
#   (651, 1),
#   (652, 1),
#   (653, 1),
#   (654, 1),
#   (655, 1),
#   (656, 1),
#   (657, 1),
#   (658, 1),
#   (659, 1),
#   (660, 1),
#   (661, 1),
#   (662, 1)],
#  [(48, 2),
#   (61, 1),
#   (77, 2),
#   (229, 1),
#   (663, 1),
#   (664, 1),
#   (665, 2),
#   (666, 1),
#   (667, 1),
#   (668, 1),
#   (669, 1),
#   (670, 1),
#   (671, 1),
#   (672, 1),
#   (673, 1)],
#  [(3, 1), (38, 1), (58, 1), (61, 1), (329, 1), (674, 1)],
#  [(5, 1),
#   (36, 1),
#   (47, 1),
#   (61, 1),
#   (95, 1),
#   (132, 1),
#   (328, 1),
#   (450, 1),
#   (513, 1),
#   (641, 1),
#   (675, 1),
#   (676, 1),
#   (677, 1),
#   (678, 1)],
#  [(3, 2),
#   (38, 1),
#   (139, 1),
#   (165, 1),
#   (194, 1),
#   (248, 1),
#   (333, 1),
#   (457, 1),
#   (465, 1),
#   (504, 1),
#   (561, 1),
#   (658, 1),
#   (679, 1),
#   (680, 1),
#   (681, 1),
#   (682, 1),
#   (683, 1),
#   (684, 1),
#   (685, 1),
#   (686, 1),
#   (687, 2),
#   (688, 1),
#   (689, 1),
#   (690, 1),
#   (691, 1),
#   (692, 1),
#   (693, 1)],
#  [(61, 1), (676, 1), (694, 1), (695, 1)],
#  [(10, 1),
#   (27, 1),
#   (38, 1),
#   (45, 1),
#   (126, 1),
#   (259, 1),
#   (328, 1),
#   (430, 1),
#   (494, 1),
#   (696, 1),
#   (697, 1),
#   (698, 1),
#   (699, 1)],
#  [(9, 1),
#   (132, 1),
#   (213, 1),
#   (322, 1),
#   (411, 1),
#   (453, 1),
#   (480, 1),
#   (482, 1),
#   (577, 1),
#   (700, 1),
#   (701, 1),
#   (702, 1),
#   (703, 1),
#   (704, 1),
#   (705, 1),
#   (706, 1)],
#  [(35, 1),
#   (61, 2),
#   (78, 1),
#   (163, 1),
#   (165, 2),
#   (229, 1),
#   (233, 1),
#   (372, 1),
#   (707, 1),
#   (708, 1),
#   (709, 1),
#   (710, 1),
#   (711, 1)],
#  [(34, 1),
#   (35, 1),
#   (74, 1),
#   (75, 1),
#   (122, 1),
#   (211, 1),
#   (427, 1),
#   (457, 1),
#   (486, 1),
#   (489, 1),
#   (712, 1),
#   (713, 1)],
#  [(26, 1),
#   (27, 1),
#   (34, 1),
#   (58, 1),
#   (61, 1),
#   (237, 1),
#   (332, 1),
#   (436, 1),
#   (486, 1),
#   (714, 1),
#   (715, 1),
#   (716, 1),
#   (717, 1)],
#  [(61, 1),
#   (137, 1),
#   (165, 1),
#   (175, 1),
#   (259, 1),
#   (288, 1),
#   (306, 1),
#   (641, 1),
#   (694, 1),
#   (718, 1)],
#  [(306, 1), (719, 1)],
#  [(19, 2),
#   (177, 1),
#   (182, 1),
#   (189, 1),
#   (241, 1),
#   (277, 2),
#   (354, 1),
#   (720, 1),
#   (721, 1)],
#  [(58, 1),
#   (61, 1),
#   (221, 1),
#   (375, 1),
#   (400, 1),
#   (494, 1),
#   (722, 1),
#   (723, 1),
#   (724, 1)],
#  [(38, 1),
#   (61, 1),
#   (75, 2),
#   (214, 1),
#   (567, 1),
#   (725, 1),
#   (726, 1),
#   (727, 1),
#   (728, 1),
#   (729, 1)],
#  [(523, 1)],
#  [(133, 1), (523, 1), (719, 1)],
#  [(27, 1),
#   (35, 1),
#   (38, 2),
#   (44, 1),
#   (61, 1),
#   (95, 1),
#   (149, 1),
#   (162, 1),
#   (448, 1),
#   (570, 1),
#   (669, 1),
#   (730, 1),
#   (731, 1),
#   (732, 1),
#   (733, 1),
#   (734, 2),
#   (735, 1),
#   (736, 1)],
#  [(38, 1),
#   (45, 1),
#   (139, 1),
#   (200, 1),
#   (453, 1),
#   (477, 1),
#   (608, 1),
#   (737, 1),
#   (738, 1),
#   (739, 1),
#   (740, 1),
#   (741, 1),
#   (742, 1),
#   (743, 1),
#   (744, 1),
#   (745, 1),
#   (746, 1),
#   (747, 1),
#   (748, 1)],
#  [(329, 1), (367, 1), (523, 1), (529, 1)],
#  [(27, 1),
#   (38, 2),
#   (41, 1),
#   (54, 1),
#   (61, 2),
#   (156, 1),
#   (162, 1),
#   (165, 3),
#   (253, 1),
#   (260, 1),
#   (302, 1),
#   (333, 1),
#   (428, 1),
#   (502, 1),
#   (749, 1),
#   (750, 1),
#   (751, 1),
#   (752, 1),
#   (753, 1),
#   (754, 1),
#   (755, 1),
#   (756, 1)],
#  [(81, 1),
#   (101, 1),
#   (132, 1),
#   (267, 1),
#   (272, 1),
#   (429, 1),
#   (467, 1),
#   (480, 1),
#   (719, 2),
#   (757, 1),
#   (758, 1),
#   (759, 1),
#   (760, 1),
#   (761, 1)],
#  [(61, 1),
#   (165, 1),
#   (305, 1),
#   (306, 1),
#   (318, 1),
#   (328, 1),
#   (762, 1),
#   (763, 1)],
#  [(3, 1),
#   (24, 1),
#   (38, 1),
#   (165, 1),
#   (328, 2),
#   (360, 1),
#   (380, 1),
#   (628, 1),
#   (755, 1),
#   (764, 1),
#   (765, 1)],
#  [(45, 2),
#   (54, 1),
#   (165, 1),
#   (310, 1),
#   (320, 1),
#   (333, 1),
#   (351, 1),
#   (361, 1),
#   (470, 1),
#   (766, 1),
#   (767, 1),
#   (768, 1),
#   (769, 1),
#   (770, 1),
#   (771, 1),
#   (772, 1),
#   (773, 1),
#   (774, 1)],
#  [(3, 1),
#   (38, 1),
#   (137, 1),
#   (165, 1),
#   (328, 1),
#   (627, 1),
#   (775, 1),
#   (776, 1),
#   (777, 1),
#   (778, 1),
#   (779, 1),
#   (780, 1),
#   (781, 1)],
#  [(38, 2), (165, 1), (312, 1), (782, 1)],
#  [(41, 1),
#   (54, 2),
#   (61, 1),
#   (103, 1),
#   (126, 1),
#   (172, 1),
#   (233, 1),
#   (258, 1),
#   (429, 2)],
#  [(5, 1), (38, 2), (47, 1), (61, 1), (165, 1), (302, 1), (328, 1), (641, 1)],
#  [(3, 3),
#   (9, 1),
#   (35, 1),
#   (44, 1),
#   (45, 2),
#   (54, 1),
#   (61, 3),
#   (75, 1),
#   (95, 1),
#   (101, 1),
#   (116, 2),
#   (122, 1),
#   (141, 2),
#   (146, 1),
#   (210, 1),
#   (258, 1),
#   (318, 1),
#   (384, 1),
#   (432, 1),
#   (467, 1),
#   (486, 1),
#   (557, 1),
#   (783, 1),
#   (784, 1),
#   (785, 1),
#   (786, 1),
#   (787, 1),
#   (788, 1),
#   (789, 1),
#   (790, 1),
#   (791, 1),
#   (792, 1)],
#  [(61, 1), (163, 1), (165, 1), (174, 1), (328, 1), (329, 1), (362, 1)],
#  [(61, 1), (328, 1)],
#  [(54, 1), (165, 1), (329, 1), (334, 1)],
#  [(160, 1), (189, 1)],
#  [(8, 1), (34, 2), (61, 1), (74, 1), (330, 1), (793, 1), (794, 1)],
#  [(5, 1),
#   (6, 1),
#   (18, 1),
#   (25, 1),
#   (26, 2),
#   (27, 3),
#   (28, 1),
#   (33, 1),
#   (35, 1),
#   (37, 1),
#   (45, 1),
#   (54, 1),
#   (55, 1),
#   (58, 1),
#   (61, 5),
#   (74, 1),
#   (75, 1),
#   (76, 1),
#   (82, 1),
#   (102, 1),
#   (103, 2),
#   (121, 1),
#   (148, 1),
#   (152, 2),
#   (163, 2),
#   (177, 1),
#   (192, 1),
#   (205, 1),
#   (210, 1),
#   (213, 1),
#   (233, 1),
#   (236, 1),
#   (257, 1),
#   (266, 1),
#   (306, 1),
#   (311, 1),
#   (323, 2),
#   (347, 1),
#   (372, 1),
#   (373, 1),
#   (387, 1),
#   (390, 1),
#   (437, 1),
#   (453, 1),
#   (470, 2),
#   (477, 1),
#   (490, 1),
#   (502, 1),
#   (508, 2),
#   (521, 1),
#   (530, 1),
#   (565, 1),
#   (606, 1),
#   (707, 1),
#   (773, 3),
#   (795, 1),
#   (796, 1),
#   (797, 1),
#   (798, 1),
#   (799, 1),
#   (800, 1),
#   (801, 1),
#   (802, 1),
#   (803, 2),
#   (804, 1),
#   (805, 1),
#   (806, 1),
#   (807, 1),
#   (808, 1),
#   (809, 1),
#   (810, 1),
#   (811, 1),
#   (812, 1),
#   (813, 1),
#   (814, 1),
#   (815, 1),
#   (816, 1),
#   (817, 1),
#   (818, 1),
#   (819, 1),
#   (820, 1),
#   (821, 1),
#   (822, 1),
#   (823, 1),
#   (824, 1),
#   (825, 1),
#   (826, 1),
#   (827, 1),
#   (828, 1),
#   (829, 2),
#   (830, 1),
#   (831, 2),
#   (832, 1),
#   (833, 1),
#   (834, 1),
#   (835, 1),
#   (836, 1),
#   (837, 1),
#   (838, 1)],
#  [(329, 1), (627, 1)],
#  [(8, 2),
#   (75, 1),
#   (122, 1),
#   (269, 2),
#   (434, 1),
#   (501, 1),
#   (719, 1),
#   (826, 1),
#   (839, 1),
#   (840, 1),
#   (841, 1)],
#  [(5, 1),
#   (38, 2),
#   (165, 1),
#   (289, 1),
#   (306, 1),
#   (373, 1),
#   (532, 1),
#   (557, 1),
#   (645, 1),
#   (719, 1),
#   (729, 1),
#   (842, 1),
#   (843, 1),
#   (844, 1),
#   (845, 1)],
#  [(61, 1), (165, 1), (311, 1), (383, 1), (515, 1), (628, 1), (846, 1)],
#  [(22, 1),
#   (61, 1),
#   (84, 1),
#   (149, 1),
#   (168, 1),
#   (174, 1),
#   (182, 1),
#   (259, 1),
#   (323, 1),
#   (372, 1),
#   (412, 1),
#   (442, 1),
#   (477, 1),
#   (496, 1),
#   (708, 2),
#   (743, 1),
#   (847, 1),
#   (848, 1),
#   (849, 1),
#   (850, 1),
#   (851, 1),
#   (852, 1),
#   (853, 1),
#   (854, 1),
#   (855, 1),
#   (856, 1),
#   (857, 1),
#   (858, 1),
#   (859, 1),
#   (860, 1)],
#  [(383, 1), (523, 1)],
#  [(26, 1),
#   (61, 1),
#   (90, 1),
#   (99, 1),
#   (436, 1),
#   (454, 1),
#   (861, 1),
#   (862, 1),
#   (863, 1)],
#  [(45, 1), (328, 1), (329, 1), (519, 1)],
#  [(61, 2),
#   (74, 1),
#   (129, 1),
#   (299, 1),
#   (306, 1),
#   (331, 1),
#   (627, 1),
#   (864, 1),
#   (865, 1)],
#  [(45, 1),
#   (75, 1),
#   (121, 1),
#   (318, 1),
#   (340, 1),
#   (866, 1),
#   (867, 1),
#   (868, 1),
#   (869, 1),
#   (870, 1),
#   (871, 1)],
#  [(10, 1),
#   (38, 1),
#   (61, 1),
#   (165, 1),
#   (328, 1),
#   (442, 1),
#   (763, 1),
#   (847, 1),
#   (872, 1)],
#  [(10, 1),
#   (38, 1),
#   (41, 1),
#   (61, 1),
#   (162, 1),
#   (328, 1),
#   (393, 1),
#   (632, 1),
#   (633, 1)],
#  [(61, 1),
#   (101, 1),
#   (489, 1),
#   (736, 1),
#   (873, 1),
#   (874, 1),
#   (875, 1),
#   (876, 1),
#   (877, 1),
#   (878, 1)],
#  [(28, 1),
#   (38, 1),
#   (54, 1),
#   (149, 1),
#   (152, 1),
#   (219, 1),
#   (323, 1),
#   (333, 1),
#   (879, 1),
#   (880, 1)],
#  [(49, 1), (194, 1), (311, 1), (609, 1), (881, 1), (882, 1)],
#  [(286, 1), (306, 1)],
#  [(8, 1),
#   (61, 2),
#   (366, 1),
#   (396, 1),
#   (525, 1),
#   (883, 1),
#   (884, 1),
#   (885, 1),
#   (886, 1)],
#  [(61, 1), (328, 1)],
#  [(49, 1),
#   (132, 1),
#   (185, 1),
#   (333, 1),
#   (453, 1),
#   (496, 1),
#   (577, 1),
#   (641, 1),
#   (887, 1),
#   (888, 1),
#   (889, 1),
#   (890, 1),
#   (891, 1)],
#  [(163, 1), (523, 1), (577, 1), (863, 1), (892, 1)],
#  [(61, 1), (165, 1), (322, 1), (328, 1), (442, 1), (893, 1)],
#  [(126, 1),
#   (233, 1),
#   (306, 1),
#   (776, 1),
#   (845, 1),
#   (894, 1),
#   (895, 1),
#   (896, 1)],
#  [(61, 1), (627, 1), (897, 1)],
#  [(38, 1),
#   (45, 1),
#   (133, 1),
#   (627, 1),
#   (648, 1),
#   (719, 1),
#   (898, 1),
#   (899, 1),
#   (900, 1),
#   (901, 1)],
#  [(61, 1),
#   (132, 2),
#   (182, 1),
#   (198, 1),
#   (233, 1),
#   (297, 1),
#   (333, 1),
#   (339, 1),
#   (560, 1),
#   (834, 1),
#   (902, 1),
#   (903, 1),
#   (904, 1),
#   (905, 1),
#   (906, 1),
#   (907, 1),
#   (908, 1),
#   (909, 1),
#   (910, 1)],
#  [(5, 1),
#   (35, 1),
#   (61, 1),
#   (192, 1),
#   (235, 1),
#   (318, 1),
#   (361, 1),
#   (814, 1),
#   (911, 1),
#   (912, 1)],
#  [(194, 1), (207, 1)],
#  [(45, 1),
#   (58, 1),
#   (61, 1),
#   (122, 1),
#   (151, 1),
#   (311, 1),
#   (598, 1),
#   (703, 1),
#   (913, 1),
#   (914, 1)],
#  [(61, 1),
#   (103, 1),
#   (121, 1),
#   (137, 1),
#   (174, 1),
#   (282, 2),
#   (287, 2),
#   (318, 1),
#   (322, 1),
#   (328, 1),
#   (386, 1),
#   (448, 1),
#   (486, 1),
#   (915, 1),
#   (916, 1),
#   (917, 1),
#   (918, 1),
#   (919, 1),
#   (920, 1),
#   (921, 1),
#   (922, 1)],
#  [(5, 2),
#   (10, 1),
#   (38, 1),
#   (47, 1),
#   (61, 1),
#   (92, 1),
#   (162, 1),
#   (226, 2),
#   (257, 2),
#   (304, 1),
#   (311, 1),
#   (329, 1),
#   (457, 1),
#   (475, 1),
#   (560, 1),
#   (611, 2),
#   (923, 1),
#   (924, 1),
#   (925, 1),
#   (926, 1),
#   (927, 1)],
#  [(0, 1),
#   (5, 1),
#   (8, 1),
#   (33, 1),
#   (34, 1),
#   (38, 1),
#   (44, 1),
#   (47, 1),
#   (58, 1),
#   (61, 1),
#   (74, 1),
#   (75, 1),
#   (113, 2),
#   (140, 1),
#   (174, 1),
#   (175, 3),
#   (176, 1),
#   (182, 1),
#   (207, 1),
#   (222, 1),
#   (226, 1),
#   (230, 1),
#   (248, 1),
#   (325, 2),
#   (333, 1),
#   (378, 1),
#   (419, 1),
#   (425, 1),
#   (458, 1),
#   (473, 1),
#   (474, 1),
#   (477, 1),
#   (486, 1),
#   (496, 1),
#   (510, 1),
#   (556, 1),
#   (665, 1),
#   (743, 1),
#   (754, 1),
#   (805, 1),
#   (823, 1),
#   (832, 1),
#   (889, 1),
#   (928, 1),
#   (929, 1),
#   (930, 1),
#   (931, 1),
#   (932, 1),
#   (933, 1),
#   (934, 1),
#   (935, 1),
#   (936, 1),
#   (937, 1),
#   (938, 2),
#   (939, 1),
#   (940, 1)],
#  [(10, 1),
#   (38, 2),
#   (45, 1),
#   (302, 1),
#   (318, 1),
#   (570, 1),
#   (618, 1),
#   (901, 1),
#   (941, 1),
#   (942, 1),
#   (943, 1)],
#  [(34, 1),
#   (35, 1),
#   (41, 2),
#   (61, 1),
#   (121, 1),
#   (162, 1),
#   (237, 1),
#   (277, 1),
#   (287, 1),
#   (331, 1),
#   (361, 1),
#   (390, 1),
#   (427, 1),
#   (489, 2),
#   (622, 1),
#   (693, 1),
#   (944, 1),
#   (945, 1),
#   (946, 1)],
#  [(74, 1),
#   (132, 1),
#   (162, 1),
#   (176, 1),
#   (265, 1),
#   (340, 1),
#   (478, 1),
#   (947, 1),
#   (948, 1),
#   (949, 1),
#   (950, 1),
#   (951, 1),
#   (952, 1)],
#  [(38, 1),
#   (61, 1),
#   (149, 1),
#   (228, 1),
#   (287, 1),
#   (328, 2),
#   (700, 1),
#   (953, 1)],
#  [(884, 1)],
#  [(884, 1)],
#  [(32, 1), (41, 1), (84, 2), (226, 1), (333, 1), (513, 1), (954, 1)],
#  [(306, 1)],
#  [(38, 1),
#   (61, 2),
#   (75, 1),
#   (103, 1),
#   (137, 1),
#   (161, 1),
#   (186, 1),
#   (248, 1),
#   (259, 1),
#   (287, 1),
#   (302, 1),
#   (312, 1),
#   (389, 1),
#   (393, 1),
#   (415, 1),
#   (425, 1),
#   (498, 1),
#   (558, 1),
#   (618, 1),
#   (644, 1),
#   (853, 1),
#   (955, 1),
#   (956, 1),
#   (957, 1),
#   (958, 1),
#   (959, 1),
#   (960, 1),
#   (961, 1),
#   (962, 1),
#   (963, 1),
#   (964, 1),
#   (965, 1)],
#  [(10, 1),
#   (28, 1),
#   (38, 1),
#   (50, 1),
#   (77, 1),
#   (101, 1),
#   (126, 1),
#   (134, 1),
#   (152, 1),
#   (162, 1),
#   (185, 1),
#   (297, 1),
#   (306, 1),
#   (321, 1),
#   (395, 1),
#   (425, 1),
#   (453, 1),
#   (476, 1),
#   (494, 1),
#   (627, 1),
#   (795, 1),
#   (966, 1),
#   (967, 1),
#   (968, 1),
#   (969, 1),
#   (970, 2),
#   (971, 1),
#   (972, 1)],
#  [(38, 1),
#   (61, 1),
#   (134, 1),
#   (174, 1),
#   (187, 1),
#   (439, 1),
#   (519, 1),
#   (609, 1),
#   (973, 1),
#   (974, 1),
#   (975, 1),
#   (976, 1),
#   (977, 1),
#   (978, 1)],
#  [(8, 2),
#   (17, 1),
#   (61, 3),
#   (287, 1),
#   (307, 1),
#   (489, 1),
#   (519, 1),
#   (747, 1),
#   (885, 1),
#   (979, 1),
#   (980, 1)],
#  [(85, 1), (165, 1), (188, 1), (206, 1), (322, 1), (981, 1)],
#  [(101, 1), (151, 1), (449, 1), (533, 1), (889, 1), (982, 1), (983, 1)],
#  [(306, 1), (467, 1), (627, 1), (984, 1)],
#  [(32, 1),
#   (61, 1),
#   (165, 1),
#   (185, 1),
#   (210, 1),
#   (215, 1),
#   (258, 1),
#   (311, 1),
#   (331, 1),
#   (489, 1),
#   (560, 1),
#   (572, 1),
#   (606, 1),
#   (924, 1),
#   (985, 1),
#   (986, 1),
#   (987, 1),
#   (988, 1)],
#  [(61, 1), (133, 1), (199, 1), (248, 1), (306, 1), (694, 1)],
#  [(8, 2),
#   (61, 2),
#   (111, 1),
#   (196, 1),
#   (287, 1),
#   (307, 1),
#   (354, 1),
#   (519, 1),
#   (885, 1),
#   (989, 1),
#   (990, 1)],
#  [(44, 1),
#   (45, 1),
#   (61, 1),
#   (122, 1),
#   (328, 1),
#   (333, 2),
#   (474, 1),
#   (487, 1),
#   (598, 1),
#   (628, 1),
#   (739, 2),
#   (847, 1),
#   (991, 1),
#   (992, 1),
#   (993, 1)],
#  [(61, 1), (295, 1), (434, 1), (467, 1), (563, 1), (994, 1), (995, 1)],
#  [(61, 1),
#   (162, 1),
#   (176, 1),
#   (837, 1),
#   (996, 1),
#   (997, 1),
#   (998, 1),
#   (999, 1)],
#  [(35, 1),
#   (44, 1),
#   (75, 1),
#   (77, 1),
#   (92, 1),
#   (95, 1),
#   (226, 1),
#   (295, 1),
#   (311, 1),
#   (437, 1),
#   (467, 1),
#   (719, 1),
#   (832, 1),
#   (973, 1),
#   (1000, 1),
#   (1001, 1),
#   (1002, 1)],
#  [(58, 1),
#   (61, 1),
#   (75, 1),
#   (102, 1),
#   (132, 1),
#   (163, 1),
#   (233, 2),
#   (334, 1),
#   (938, 1),
#   (1003, 1),
#   (1004, 1),
#   (1005, 1),
#   (1006, 1),
#   (1007, 1)],
#  [(61, 1), (328, 1), (383, 1)],
#  [(3, 1),
#   (5, 1),
#   (41, 1),
#   (54, 1),
#   (61, 1),
#   (168, 1),
#   (173, 1),
#   (210, 1),
#   (258, 1),
#   (565, 1),
#   (977, 1),
#   (1008, 1),
#   (1009, 1)],
#  [(95, 1),
#   (122, 1),
#   (126, 1),
#   (132, 1),
#   (151, 2),
#   (165, 1),
#   (260, 1),
#   (302, 1),
#   (306, 1),
#   (319, 1),
#   (325, 1),
#   (530, 1),
#   (739, 1),
#   (786, 1),
#   (1010, 1),
#   (1011, 1),
#   (1012, 1),
#   (1013, 1),
#   (1014, 1),
#   (1015, 1)],
#  [(61, 1),
#   (160, 1),
#   (328, 3),
#   (951, 1),
#   (999, 1),
#   (1016, 1),
#   (1017, 1),
#   (1018, 1)],
#  [(329, 1), (719, 1), (1019, 1)],
#  [(0, 1),
#   (28, 1),
#   (33, 1),
#   (34, 2),
#   (35, 1),
#   (38, 2),
#   (44, 2),
#   (52, 1),
#   (54, 1),
#   (58, 1),
#   (61, 5),
#   (74, 3),
#   (75, 2),
#   (78, 1),
#   (95, 4),
#   (97, 1),
#   (103, 1),
#   (129, 1),
#   (137, 1),
#   (151, 2),
#   (162, 1),
#   (165, 1),
#   (175, 3),
#   (205, 1),
#   (230, 1),
#   (233, 1),
#   (258, 1),
#   (259, 1),
#   (262, 1),
#   (269, 1),
#   (287, 1),
#   (288, 2),
#   (307, 1),
#   (312, 1),
#   (323, 2),
#   (325, 1),
#   (358, 1),
#   (367, 1),
#   (397, 1),
#   (405, 1),
#   (419, 1),
#   (427, 2),
#   (434, 2),
#   (467, 1),
#   (484, 1),
#   (486, 2),
#   (496, 4),
#   (501, 1),
#   (511, 1),
#   (561, 1),
#   (565, 2),
#   (598, 1),
#   (606, 1),
#   (638, 1),
#   (641, 5),
#   (644, 1),
#   (672, 1),
#   (694, 1),
#   (792, 1),
#   (805, 2),
#   (806, 1),
#   (807, 1),
#   (811, 1),
#   (902, 1),
#   (963, 1),
#   (978, 1),
#   (1020, 1),
#   (1021, 1),
#   (1022, 1),
#   (1023, 1),
#   (1024, 1),
#   (1025, 1),
#   (1026, 2),
#   (1027, 1),
#   (1028, 1),
#   (1029, 1),
#   (1030, 1),
#   (1031, 2),
#   (1032, 1),
#   (1033, 1),
#   (1034, 1),
#   (1035, 1),
#   (1036, 1),
#   (1037, 1),
#   (1038, 1),
#   (1039, 1),
#   (1040, 3),
#   (1041, 1),
#   (1042, 2),
#   (1043, 1),
#   (1044, 1),
#   (1045, 1),
#   (1046, 1),
#   (1047, 1),
#   (1048, 1),
#   (1049, 1),
#   (1050, 1),
#   (1051, 2),
#   (1052, 1),
#   (1053, 1),
#   (1054, 1),
#   (1055, 1),
#   (1056, 1),
#   (1057, 1),
#   (1058, 2),
#   (1059, 1),
#   (1060, 1),
#   (1061, 1),
#   (1062, 1)],
#  [(54, 1),
#   (61, 1),
#   (77, 1),
#   (221, 1),
#   (311, 1),
#   (719, 1),
#   (749, 1),
#   (916, 1),
#   (1023, 1),
#   (1063, 1),
#   (1064, 1),
#   (1065, 1),
#   (1066, 1),
#   (1067, 1),
#   (1068, 1),
#   (1069, 1),
#   (1070, 1)],
#  [(3, 1),
#   (41, 2),
#   (45, 1),
#   (61, 2),
#   (112, 1),
#   (163, 1),
#   (165, 1),
#   (277, 1),
#   (306, 1),
#   (311, 1),
#   (328, 1),
#   (467, 1),
#   (549, 1),
#   (997, 1),
#   (1071, 1),
#   (1072, 1),
#   (1073, 1),
#   (1074, 1),
#   (1075, 1),
#   (1076, 1),
#   (1077, 1)],
#  [(1078, 1), (1079, 1), (1080, 1)],
#  [(10, 1), (61, 1), (494, 2)],
#  [(45, 1), (328, 1), (362, 1)],
#  [(38, 1), (248, 1), (367, 1), (628, 1)],
#  [(0, 1),
#   (61, 1),
#   (174, 1),
#   (306, 1),
#   (627, 1),
#   (832, 1),
#   (974, 1),
#   (1081, 1),
#   (1082, 1),
#   (1083, 1)],
#  [(194, 1), (209, 1), (302, 1), (523, 1), (1084, 1)],
#  [(61, 1),
#   (133, 1),
#   (233, 1),
#   (302, 1),
#   (311, 1),
#   (318, 1),
#   (324, 1),
#   (328, 1),
#   (432, 1),
#   (530, 1),
#   (563, 1),
#   (612, 1),
#   (900, 1),
#   (1066, 1),
#   (1085, 1),
#   (1086, 2),
#   (1087, 1),
#   (1088, 1)],
#  [(214, 1), (329, 1), (650, 1), (1089, 1)],
#  [(38, 1),
#   (58, 1),
#   (61, 1),
#   (103, 1),
#   (163, 1),
#   (165, 2),
#   (237, 1),
#   (278, 1),
#   (307, 1),
#   (390, 1),
#   (425, 1),
#   (533, 1),
#   (736, 1),
#   (1056, 1)],
#  [(1090, 1), (1091, 1)],
#  [(38, 1)],
#  [(61, 1), (163, 1), (302, 1), (306, 1), (478, 1)],
#  [(3, 1),
#   (5, 1),
#   (27, 1),
#   (29, 1),
#   (35, 1),
#   (37, 1),
#   (41, 1),
#   (44, 1),
#   (58, 1),
#   (61, 2),
#   (79, 2),
#   (95, 1),
#   (98, 1),
#   (137, 1),
#   (148, 1),
#   (165, 2),
#   (169, 1),
#   (174, 1),
#   (190, 2),
#   (198, 1),
#   (208, 1),
#   (211, 1),
#   (217, 1),
#   (220, 1),
#   (226, 1),
#   (230, 2),
#   (248, 1),
#   (259, 1),
#   (302, 2),
#   (306, 3),
#   (415, 1),
#   (429, 2),
#   (467, 1),
#   (477, 2),
#   (496, 3),
#   (521, 1),
#   (576, 1),
#   (606, 1),
#   (612, 1),
#   (641, 2),
#   (659, 1),
#   (679, 1),
#   (682, 1),
#   (686, 1),
#   (743, 1),
#   (817, 1),
#   (1042, 1),
#   (1092, 1),
#   (1093, 1),
#   (1094, 1),
#   (1095, 1),
#   (1096, 1),
#   (1097, 1),
#   (1098, 2),
#   (1099, 1),
#   (1100, 1),
#   (1101, 1),
#   (1102, 1),
#   (1103, 1),
#   (1104, 1),
#   (1105, 1),
#   (1106, 1),
#   (1107, 1),
#   (1108, 1),
#   (1109, 1),
#   (1110, 1),
#   (1111, 1),
#   (1112, 1),
#   (1113, 1),
#   (1114, 1),
#   (1115, 1),
#   (1116, 1),
#   (1117, 1),
#   (1118, 1),
#   (1119, 1),
#   (1120, 1),
#   (1121, 1),
#   (1122, 3),
#   (1123, 1)],
#  [(74, 1), (122, 1), (299, 1), (427, 1), (641, 1), (1124, 1)],
#  [(53, 1), (163, 1), (165, 1), (206, 1), (347, 1), (697, 1), (1125, 1)],
#  [(311, 1), (713, 1)],
#  [(38, 1), (165, 1), (442, 1), (866, 1)],
#  [(38, 1), (165, 1), (1126, 1)],
#  [(2, 1),
#   (5, 2),
#   (10, 2),
#   (11, 1),
#   (25, 1),
#   (27, 2),
#   (28, 1),
#   (35, 2),
#   (38, 5),
#   (45, 1),
#   (49, 1),
#   (60, 1),
#   (61, 7),
#   (75, 1),
#   (83, 1),
#   (103, 3),
#   (126, 1),
#   (131, 2),
#   (165, 1),
#   (175, 2),
#   (176, 1),
#   (182, 1),
#   (185, 2),
#   (191, 1),
#   (212, 1),
#   (222, 1),
#   (233, 1),
#   (235, 1),
#   (238, 1),
#   (259, 1),
#   (265, 1),
#   (267, 1),
#   (302, 2),
#   (304, 1),
#   (306, 1),
#   (324, 1),
#   (329, 1),
#   (333, 3),
#   (338, 1),
#   (372, 1),
#   (373, 1),
#   (380, 1),
#   (397, 1),
#   (414, 1),
#   (425, 5),
#   (434, 2),
#   (436, 2),
#   (439, 1),
#   (478, 1),
#   (489, 1),
#   (494, 1),
#   (537, 1),
#   (567, 1),
#   (622, 1),
#   (815, 1),
#   (863, 2),
#   (943, 1),
#   (1017, 1),
#   (1100, 1),
#   (1123, 1),
#   (1127, 1),
#   (1128, 1),
#   (1129, 1),
#   (1130, 1),
#   (1131, 1),
#   (1132, 1),
#   (1133, 1),
#   (1134, 1),
#   (1135, 1),
#   (1136, 1),
#   (1137, 1),
#   (1138, 1),
#   (1139, 1),
#   (1140, 1),
#   (1141, 1),
#   (1142, 1),
#   (1143, 1),
#   (1144, 1),
#   (1145, 1),
#   (1146, 1),
#   (1147, 1),
#   (1148, 1),
#   (1149, 1),
#   (1150, 1),
#   (1151, 1),
#   (1152, 1),
#   (1153, 1),
#   (1154, 1),
#   (1155, 1),
#   (1156, 1),
#   (1157, 1),
#   (1158, 1),
#   (1159, 1),
#   (1160, 1),
#   (1161, 1),
#   (1162, 1),
#   (1163, 1),
#   (1164, 1),
#   (1165, 1),
#   (1166, 1),
#   (1167, 1),
#   (1168, 2),
#   (1169, 1)],
#  [(248, 1), (306, 1), (719, 1), (1170, 1)],
#  [(8, 1),
#   (61, 2),
#   (79, 1),
#   (129, 1),
#   (167, 1),
#   (287, 1),
#   (322, 1),
#   (577, 1),
#   (628, 1),
#   (1171, 1),
#   (1172, 1),
#   (1173, 1)],
#  [(38, 1), (248, 1), (306, 1), (719, 1)],
#  [(5, 1),
#   (29, 1),
#   (45, 1),
#   (47, 1),
#   (61, 1),
#   (149, 1),
#   (306, 1),
#   (307, 1),
#   (359, 1),
#   (372, 1),
#   (380, 1),
#   (667, 1),
#   (694, 1),
#   (780, 1),
#   (1174, 1),
#   (1175, 1),
#   (1176, 1)],
#  [(38, 1), (61, 1), (165, 1), (1177, 1)],
#  [(54, 1),
#   (75, 1),
#   (139, 1),
#   (295, 1),
#   (333, 2),
#   (334, 1),
#   (454, 1),
#   (467, 1),
#   (536, 1),
#   (563, 1),
#   (719, 1),
#   (723, 1),
#   (1178, 1),
#   (1179, 1)],
#  [(5, 1),
#   (61, 1),
#   (132, 1),
#   (230, 1),
#   (328, 1),
#   (339, 1),
#   (387, 1),
#   (521, 1),
#   (560, 1)],
#  [(5, 1),
#   (42, 1),
#   (47, 1),
#   (54, 1),
#   (61, 1),
#   (77, 1),
#   (133, 1),
#   (173, 1),
#   (209, 1),
#   (221, 1),
#   (258, 1),
#   (302, 2),
#   (306, 3),
#   (322, 1),
#   (383, 1),
#   (397, 1),
#   (523, 1),
#   (565, 1),
#   (582, 1),
#   (863, 1),
#   (1180, 1),
#   (1181, 1),
#   (1182, 1),
#   (1183, 1)],
#  [(38, 1),
#   (45, 1),
#   (61, 1),
#   (102, 1),
#   (277, 1),
#   (328, 1),
#   (333, 1),
#   (519, 1),
#   (1041, 1),
#   (1184, 1),
#   (1185, 1)],
#  [(103, 1), (135, 1), (651, 1)],
#  [(38, 1),
#   (45, 1),
#   (126, 1),
#   (132, 1),
#   (137, 1),
#   (165, 1),
#   (174, 1),
#   (272, 1),
#   (287, 1),
#   (318, 1),
#   (328, 1),
#   (519, 1),
#   (643, 1),
#   (700, 1),
#   (719, 2),
#   (901, 1),
#   (941, 1),
#   (1186, 1),
#   (1187, 1),
#   (1188, 1)],
#  [(98, 1), (467, 1), (1189, 1), (1190, 1)],
#  [(28, 1),
#   (32, 1),
#   (45, 1),
#   (54, 1),
#   (61, 1),
#   (258, 1),
#   (311, 1),
#   (326, 1),
#   (333, 1),
#   (477, 1),
#   (786, 1),
#   (910, 1),
#   (1094, 1),
#   (1191, 1),
#   (1192, 1),
#   (1193, 1)],
#  [(165, 1), (318, 1)],
#  [(61, 1), (523, 1), (1194, 1)],
#  [(1195, 1)],
#  [(322, 1)],
#  [(45, 1),
#   (163, 1),
#   (165, 1),
#   (323, 1),
#   (328, 1),
#   (343, 1),
#   (429, 1),
#   (609, 1),
#   (1196, 1)],
#  [(45, 1),
#   (61, 1),
#   (287, 1),
#   (318, 1),
#   (407, 1),
#   (1197, 1),
#   (1198, 1),
#   (1199, 1)],
#  [(329, 1)],
#  [(38, 2),
#   (61, 1),
#   (137, 1),
#   (151, 1),
#   (165, 1),
#   (185, 1),
#   (311, 1),
#   (322, 1),
#   (335, 1),
#   (959, 1),
#   (1166, 1),
#   (1200, 1)],
#  [(35, 2),
#   (61, 1),
#   (74, 1),
#   (75, 1),
#   (132, 1),
#   (176, 1),
#   (288, 1),
#   (370, 1),
#   (467, 1),
#   (577, 1),
#   (628, 1),
#   (999, 1),
#   (1201, 1),
#   (1202, 1),
#   (1203, 2),
#   (1204, 1),
#   (1205, 1),
#   (1206, 1),
#   (1207, 1),
#   (1208, 1)],
#  [(5, 2),
#   (10, 2),
#   (35, 1),
#   (38, 3),
#   (44, 1),
#   (45, 1),
#   (61, 5),
#   (66, 2),
#   (74, 1),
#   (83, 1),
#   (84, 2),
#   (95, 1),
#   (98, 1),
#   (102, 1),
#   (126, 1),
#   (129, 1),
#   (148, 1),
#   (151, 2),
#   (165, 1),
#   (172, 1),
#   (182, 1),
#   (185, 1),
#   (194, 1),
#   (206, 1),
#   (213, 1),
#   (230, 1),
#   (233, 2),
#   (259, 1),
#   (286, 1),
#   (307, 2),
#   (310, 1),
#   (320, 1),
#   (322, 1),
#   (323, 1),
#   (325, 1),
#   (330, 1),
#   (332, 1),
#   (343, 1),
#   (352, 1),
#   (357, 1),
#   (374, 1),
#   (385, 1),
#   (420, 1),
#   (427, 1),
#   (434, 1),
#   (449, 1),
#   (450, 1),
#   (467, 1),
#   (469, 1),
#   (489, 1),
#   (494, 1),
#   (496, 1),
#   (503, 1),
#   (533, 1),
#   (557, 1),
#   (560, 1),
#   (606, 1),
#   (609, 1),
#   (643, 1),
#   (645, 1),
#   (703, 1),
#   (717, 1),
#   (755, 1),
#   (756, 1),
#   (902, 1),
#   (916, 1),
#   (924, 1),
#   (941, 1),
#   (957, 1),
#   (1032, 1),
#   (1046, 2),
#   (1049, 1),
#   (1057, 1),
#   (1077, 1),
#   (1168, 1),
#   (1203, 1),
#   (1206, 1),
#   (1209, 2),
#   (1210, 1),
#   (1211, 1),
#   (1212, 1),
#   (1213, 1),
#   (1214, 1),
#   (1215, 1),
#   (1216, 1),
#   (1217, 1),
#   (1218, 1),
#   (1219, 1),
#   (1220, 1),
#   (1221, 1),
#   (1222, 1),
#   (1223, 1),
#   (1224, 1),
#   (1225, 1),
#   (1226, 1),
#   (1227, 1),
#   (1228, 2),
#   (1229, 1),
#   (1230, 1),
#   (1231, 3),
#   (1232, 1),
#   (1233, 1),
#   (1234, 1),
#   (1235, 1),
#   (1236, 1),
#   (1237, 2)],
#  [(38, 1), (165, 1)],
#  [(38, 1), (61, 1), (287, 1), (306, 1)],
#  [(35, 1), (56, 1), (61, 1), (436, 1), (1238, 1), (1239, 1)],
#  [(54, 1),
#   (165, 1),
#   (174, 1),
#   (190, 1),
#   (306, 1),
#   (334, 1),
#   (442, 1),
#   (607, 1),
#   (627, 1)],
#  [(45, 1), (328, 1)],
#  [(58, 1),
#   (161, 1),
#   (176, 1),
#   (196, 2),
#   (237, 1),
#   (250, 1),
#   (260, 1),
#   (302, 1),
#   (306, 1),
#   (374, 1),
#   (434, 1),
#   (469, 1),
#   (477, 1),
#   (536, 1),
#   (1119, 1),
#   (1240, 2),
#   (1241, 1),
#   (1242, 1),
#   (1243, 1)],
#  [(14, 1),
#   (61, 1),
#   (95, 2),
#   (132, 1),
#   (165, 2),
#   (319, 1),
#   (442, 1),
#   (496, 1),
#   (513, 1),
#   (613, 1),
#   (643, 1),
#   (731, 1),
#   (768, 1),
#   (902, 1),
#   (1244, 1),
#   (1245, 1),
#   (1246, 1),
#   (1247, 1),
#   (1248, 1)],
#  [(45, 2), (328, 2), (853, 1), (864, 1), (1249, 1)],
#  [(45, 1),
#   (122, 1),
#   (292, 1),
#   (322, 1),
#   (357, 1),
#   (530, 1),
#   (609, 1),
#   (1250, 2),
#   (1251, 1),
#   (1252, 1)],
#  [(8, 1),
#   (61, 1),
#   (174, 1),
#   (287, 1),
#   (332, 1),
#   (556, 1),
#   (694, 1),
#   (901, 1),
#   (1253, 1),
#   (1254, 1)],
#  [(34, 1),
#   (61, 2),
#   (74, 1),
#   (75, 3),
#   (95, 1),
#   (103, 1),
#   (126, 1),
#   (141, 1),
#   (146, 1),
#   (174, 1),
#   (182, 1),
#   (213, 1),
#   (219, 1),
#   (253, 1),
#   (254, 1),
#   (259, 1),
#   (309, 2),
#   (362, 1),
#   (386, 1),
#   (509, 1),
#   (611, 1),
#   (617, 1),
#   (619, 1),
#   (649, 1),
#   (715, 1),
#   (774, 1),
#   (811, 1),
#   (935, 1),
#   (941, 1),
#   (974, 1),
#   (1048, 2),
#   (1130, 1),
#   (1154, 1),
#   (1158, 1),
#   (1166, 1),
#   (1189, 1),
#   (1218, 2),
#   (1232, 1),
#   (1255, 1),
#   (1256, 1),
#   (1257, 2),
#   (1258, 1),
#   (1259, 1),
#   (1260, 1),
#   (1261, 4),
#   (1262, 1),
#   (1263, 1),
#   (1264, 1),
#   (1265, 1),
#   (1266, 1),
#   (1267, 1),
#   (1268, 1),
#   (1269, 1),
#   (1270, 1),
#   (1271, 1),
#   (1272, 1),
#   (1273, 1),
#   (1274, 1),
#   (1275, 1),
#   (1276, 1),
#   (1277, 1),
#   (1278, 1),
#   (1279, 1),
#   (1280, 1),
#   (1281, 1),
#   (1282, 3),
#   (1283, 3),
#   (1284, 1),
#   (1285, 1),
#   (1286, 1),
#   (1287, 1),
#   (1288, 2),
#   (1289, 1),
#   (1290, 1),
#   (1291, 3)],
#  [(45, 1), (489, 1), (495, 1), (1292, 1), (1293, 1)],
#  [(58, 1), (61, 2), (436, 1), (454, 1), (1231, 1), (1284, 1), (1294, 1)],
#  [(31, 1),
#   (200, 1),
#   (425, 1),
#   (477, 1),
#   (1023, 1),
#   (1091, 1),
#   (1295, 1),
#   (1296, 1)],
#  [(88, 1), (104, 1), (148, 1), (175, 1), (354, 2), (617, 1), (1297, 1)],
#  [(28, 1), (61, 1), (165, 1), (442, 1), (786, 1)],
#  [(53, 1), (61, 1), (577, 1), (628, 1), (700, 1), (1298, 1), (1299, 1)],
#  [(8, 1), (39, 1), (248, 1), (328, 1), (628, 1), (1173, 1), (1300, 1)],
#  [(8, 1),
#   (28, 1),
#   (41, 1),
#   (61, 1),
#   (74, 1),
#   (79, 1),
#   (98, 1),
#   (192, 1),
#   (253, 1),
#   (277, 1),
#   (434, 1),
#   (477, 1),
#   (523, 1),
#   (577, 1),
#   (694, 1),
#   (776, 1),
#   (1086, 1),
#   (1301, 1),
#   (1302, 1),
#   (1303, 1)],
#  [(287, 1)],
#  [(306, 1), (719, 1)],
#  [(11, 2),
#   (36, 1),
#   (38, 2),
#   (56, 1),
#   (58, 1),
#   (60, 1),
#   (61, 3),
#   (77, 1),
#   (122, 1),
#   (139, 1),
#   (163, 1),
#   (165, 1),
#   (173, 1),
#   (174, 1),
#   (213, 1),
#   (264, 1),
#   (287, 1),
#   (306, 1),
#   (311, 1),
#   (333, 1),
#   (334, 1),
#   (340, 1),
#   (427, 1),
#   (466, 1),
#   (510, 1),
#   (533, 1),
#   (675, 1),
#   (763, 2),
#   (780, 1),
#   (786, 1),
#   (795, 1),
#   (973, 1),
#   (1026, 1),
#   (1160, 1),
#   (1304, 1),
#   (1305, 1),
#   (1306, 1),
#   (1307, 1),
#   (1308, 1),
#   (1309, 1),
#   (1310, 1),
#   (1311, 1),
#   (1312, 1),
#   (1313, 1)],
#  [(0, 1),
#   (10, 4),
#   (11, 1),
#   (13, 1),
#   (24, 1),
#   (26, 2),
#   (27, 1),
#   (28, 1),
#   (36, 2),
#   (38, 1),
#   (45, 1),
#   (47, 1),
#   (61, 7),
#   (73, 1),
#   (74, 3),
#   (75, 1),
#   (77, 2),
#   (98, 1),
#   (99, 1),
#   (102, 2),
#   (112, 2),
#   (124, 1),
#   (127, 1),
#   (137, 1),
#   (156, 1),
#   (162, 1),
#   (166, 1),
#   (219, 1),
#   (221, 2),
#   (227, 1),
#   (230, 1),
#   (236, 1),
#   (237, 1),
#   (253, 1),
#   (277, 1),
#   (302, 2),
#   (306, 3),
#   (307, 1),
#   (311, 1),
#   (318, 1),
#   (329, 2),
#   (331, 1),
#   (332, 1),
#   (334, 1),
#   (354, 1),
#   (357, 1),
#   (369, 1),
#   (372, 1),
#   (379, 1),
#   (385, 2),
#   (400, 1),
#   (425, 3),
#   (427, 1),
#   (440, 1),
#   (442, 1),
#   (453, 2),
#   (461, 1),
#   (467, 1),
#   (483, 2),
#   (486, 1),
#   (509, 1),
#   (530, 1),
#   (532, 1),
#   (534, 1),
#   (557, 1),
#   (565, 1),
#   (567, 1),
#   (589, 1),
#   (623, 1),
#   (652, 1),
#   (695, 1),
#   (703, 1),
#   (809, 1),
#   (858, 1),
#   (869, 1),
#   (901, 1),
#   (903, 1),
#   (916, 1),
#   (941, 1),
#   (943, 2),
#   (1004, 1),
#   (1023, 1),
#   (1053, 1),
#   (1060, 1),
#   (1106, 1),
#   (1152, 1),
#   (1210, 1),
#   (1231, 2),
#   (1282, 1),
#   (1288, 1),
#   (1302, 1),
#   (1314, 1),
#   (1315, 1),
#   (1316, 1),
#   (1317, 1),
#   (1318, 1),
#   (1319, 1),
#   (1320, 1),
#   (1321, 1),
#   (1322, 1),
#   (1323, 1),
#   (1324, 1),
#   (1325, 1),
#   (1326, 1),
#   (1327, 1),
#   (1328, 1),
#   (1329, 1),
#   (1330, 1),
#   (1331, 1),
#   (1332, 1),
#   (1333, 1),
#   (1334, 1),
#   (1335, 1),
#   (1336, 1),
#   (1337, 1),
#   (1338, 1),
#   (1339, 1),
#   (1340, 1),
#   (1341, 1),
#   (1342, 1),
#   (1343, 1),
#   (1344, 1),
#   (1345, 1),
#   (1346, 1),
#   (1347, 1),
#   (1348, 1),
#   (1349, 1),
#   (1350, 1),
#   (1351, 1),
#   (1352, 1),
#   (1353, 1),
#   (1354, 1),
#   (1355, 1),
#   (1356, 1),
#   (1357, 1),
#   (1358, 1),
#   (1359, 1),
#   (1360, 1),
#   (1361, 1),
#   (1362, 1),
#   (1363, 1),
#   (1364, 1),
#   (1365, 1),
#   (1366, 1),
#   (1367, 1),
#   (1368, 1),
#   (1369, 1),
#   (1370, 1),
#   (1371, 1),
#   (1372, 1),
#   (1373, 1),
#   (1374, 1),
#   (1375, 1),
#   (1376, 1),
#   (1377, 1),
#   (1378, 1),
#   (1379, 1),
#   (1380, 1),
#   (1381, 1),
#   (1382, 1)],
#  [(27, 1),
#   (41, 1),
#   (44, 1),
#   (55, 1),
#   (61, 2),
#   (75, 2),
#   (79, 1),
#   (95, 1),
#   (123, 1),
#   (133, 1),
#   (139, 1),
#   (221, 2),
#   (236, 1),
#   (314, 1),
#   (322, 1),
#   (323, 2),
#   (333, 1),
#   (390, 1),
#   (500, 1),
#   (565, 1),
#   (748, 1),
#   (879, 1),
#   (900, 1),
#   (935, 1),
#   (954, 2),
#   (1012, 1),
#   (1115, 1),
#   (1128, 1),
#   (1171, 1),
#   (1200, 1),
#   (1326, 1),
#   (1383, 1),
#   (1384, 1),
#   (1385, 1),
#   (1386, 1),
#   (1387, 1),
#   (1388, 1),
#   (1389, 1),
#   (1390, 1),
#   (1391, 1),
#   (1392, 1)],
#  [(61, 1), (75, 1), (308, 1), (372, 1), (642, 1), (732, 1), (1339, 1)],
#  [(38, 1), (209, 1), (248, 1), (302, 1)],
#  [(187, 1), (1123, 1)],
#  [(61, 1), (329, 1), (577, 1), (977, 1)],
#  [(10, 1), (35, 1), (61, 2), (436, 1), (458, 1)],
#  [(61, 1),
#   (132, 1),
#   (133, 1),
#   (258, 1),
#   (306, 1),
#   (307, 1),
#   (598, 1),
#   (1393, 1)],
#  [(61, 1), (132, 1), (248, 1), (306, 1), (1154, 1), (1394, 1), (1395, 1)],
#  [(11, 1),
#   (28, 1),
#   (29, 1),
#   (38, 3),
#   (41, 1),
#   (45, 1),
#   (54, 1),
#   (61, 3),
#   (66, 1),
#   (106, 1),
#   (131, 1),
#   (133, 1),
#   (151, 1),
#   (152, 1),
#   (165, 2),
#   (173, 1),
#   (306, 1),
#   (307, 1),
#   (311, 1),
#   (316, 1),
#   (328, 1),
#   (333, 1),
#   (335, 1),
#   (357, 1),
#   (374, 1),
#   (411, 1),
#   (427, 1),
#   (482, 1),
#   (486, 2),
#   (627, 1),
#   (686, 1),
#   (688, 1),
#   (731, 1),
#   (735, 2),
#   (803, 1),
#   (805, 1),
#   (853, 1),
#   (1028, 1),
#   (1046, 1),
#   (1175, 1),
#   (1228, 1),
#   (1232, 1),
#   (1236, 2),
#   (1396, 1),
#   (1397, 1),
#   (1398, 1),
#   (1399, 1),
#   (1400, 1),
#   (1401, 1),
#   (1402, 1),
#   (1403, 1),
#   (1404, 1),
#   (1405, 1),
#   (1406, 1),
#   (1407, 1),
#   (1408, 1),
#   (1409, 1),
#   (1410, 2)],
#  [(10, 1),
#   (35, 1),
#   (58, 1),
#   (61, 2),
#   (122, 1),
#   (139, 1),
#   (212, 1),
#   (214, 1),
#   (276, 1),
#   (306, 2),
#   (450, 1),
#   (467, 1),
#   (570, 1),
#   (1156, 1),
#   (1168, 1),
#   (1411, 1),
#   (1412, 1)],
#  [(33, 1), (174, 1), (328, 1), (412, 1)],
#  [(132, 1), (165, 2), (329, 1), (641, 1)],
#  [(61, 1), (163, 1), (427, 1), (1009, 1), (1026, 1), (1413, 1), (1414, 1)],
#  [(137, 1), (217, 1), (467, 1), (1092, 1)],
#  [(28, 1),
#   (61, 1),
#   (75, 1),
#   (79, 1),
#   (287, 1),
#   (323, 1),
#   (328, 1),
#   (570, 1),
#   (694, 1),
#   (1415, 1),
#   (1416, 1)],
#  [(41, 1), (44, 1), (265, 1), (329, 1), (345, 1), (1417, 1), (1418, 1)],
#  [(38, 1), (61, 1), (523, 1), (1419, 1)],
#  [(329, 1)],
#  [(34, 1), (74, 1), (75, 1), (126, 1), (229, 1), (258, 1), (328, 1)],
#  [(0, 1),
#   (3, 1),
#   (11, 2),
#   (24, 1),
#   (26, 1),
#   (28, 3),
#   (29, 2),
#   (33, 1),
#   (34, 2),
#   (35, 1),
#   (36, 1),
#   (37, 3),
#   (38, 3),
#   (41, 1),
#   (45, 1),
#   (49, 1),
#   (50, 1),
#   (55, 1),
#   (58, 2),
#   (61, 14),
#   (74, 3),
#   (75, 1),
#   (78, 1),
#   (84, 1),
#   (92, 2),
#   (103, 1),
#   (113, 10),
#   (126, 1),
#   (139, 1),
#   (151, 1),
#   (163, 1),
#   (165, 2),
#   (168, 2),
#   (172, 1),
#   (175, 12),
#   (182, 1),
#   (187, 1),
#   (210, 1),
#   (213, 1),
#   (217, 1),
#   (219, 1),
#   (221, 1),
#   (222, 1),
#   (233, 2),
#   (238, 1),
#   (253, 1),
#   (257, 1),
#   (259, 1),
#   (268, 1),
#   (287, 9),
#   (290, 1),
#   (294, 1),
#   (295, 1),
#   (297, 2),
#   (299, 1),
#   (304, 1),
#   (305, 10),
#   (311, 1),
#   (312, 2),
#   (324, 1),
#   (327, 1),
#   (328, 1),
#   (330, 5),
#   (331, 2),
#   (357, 1),
#   (367, 1),
#   (370, 1),
#   (373, 1),
#   (374, 1),
#   (376, 1),
#   (378, 4),
#   (386, 1),
#   (389, 1),
#   (390, 1),
#   (400, 5),
#   (415, 2),
#   (419, 2),
#   (427, 1),
#   (434, 2),
#   (436, 1),
#   (449, 1),
#   (453, 1),
#   (466, 2),
#   (467, 1),
#   (480, 1),
#   (483, 1),
#   (486, 2),
#   (494, 1),
#   (506, 5),
#   (507, 4),
#   (515, 1),
#   (530, 1),
#   (532, 1),
#   (567, 1),
#   (568, 1),
#   (570, 2),
#   (577, 1),
#   (606, 1),
#   (607, 2),
#   (638, 1),
#   (644, 4),
#   (672, 1),
#   (675, 1),
#   (676, 1),
#   (688, 1),
#   (722, 1),
#   (735, 2),
#   (743, 1),
#   (759, 1),
#   (788, 1),
#   (805, 1),
#   (809, 1),
#   (811, 1),
#   (817, 1),
#   (847, 1),
#   (851, 1),
#   (863, 1),
#   (885, 1),
#   (903, 1),
#   (916, 1),
#   (941, 1),
#   (951, 1),
#   (959, 1),
#   (960, 2),
#   (973, 2),
#   (984, 1),
#   (999, 3),
#   (1004, 1),
#   (1026, 2),
#   (1057, 1),
#   (1058, 2),
#   (1060, 1),
#   (1084, 1),
#   (1102, 1),
#   (1115, 2),
#   (1117, 1),
#   (1189, 1),
#   (1210, 1),
#   (1217, 1),
#   (1231, 1),
#   (1356, 1),
#   (1370, 1),
#   (1376, 1),
#   (1408, 1),
#   (1420, 2),
#   (1421, 1),
#   (1422, 1),
#   (1423, 1),
#   (1424, 2),
#   (1425, 1),
#   (1426, 1),
#   (1427, 1),
#   (1428, 1),
#   (1429, 1),
#   (1430, 1),
#   (1431, 1),
#   (1432, 3),
#   (1433, 1),
#   (1434, 1),
#   (1435, 2),
#   (1436, 1),
#   (1437, 1),
#   (1438, 1),
#   (1439, 1),
#   (1440, 1),
#   (1441, 1),
#   (1442, 1),
#   (1443, 1),
#   (1444, 1),
#   (1445, 1),
#   (1446, 1),
#   (1447, 1),
#   (1448, 1),
#   (1449, 1),
#   (1450, 1),
#   (1451, 4),
#   (1452, 1),
#   (1453, 1),
#   (1454, 1),
#   (1455, 1),
#   (1456, 1),
#   (1457, 1),
#   (1458, 1),
#   (1459, 1),
#   (1460, 2),
#   (1461, 1),
#   (1462, 1),
#   (1463, 1),
#   (1464, 1),
#   (1465, 1),
#   (1466, 1),
#   (1467, 1),
#   (1468, 1),
#   (1469, 2),
#   (1470, 1),
#   (1471, 1),
#   (1472, 1),
#   (1473, 1),
#   (1474, 1),
#   (1475, 1),
#   (1476, 1),
#   (1477, 1),
#   (1478, 1),
#   (1479, 1),
#   (1480, 1),
#   (1481, 1),
#   (1482, 1),
#   (1483, 2),
#   (1484, 1),
#   (1485, 1),
#   (1486, 1),
#   (1487, 1),
#   (1488, 1),
#   (1489, 1),
#   (1490, 1),
#   (1491, 2),
#   (1492, 1),
#   (1493, 1),
#   (1494, 1),
#   (1495, 2),
#   (1496, 1)],
#  [(28, 1),
#   (54, 1),
#   (61, 1),
#   (132, 1),
#   (182, 1),
#   (209, 1),
#   (258, 1),
#   (361, 1),
#   (786, 1),
#   (857, 1),
#   (863, 1),
#   (1043, 1),
#   (1154, 1),
#   (1497, 1)],
#  [(0, 1),
#   (10, 1),
#   (34, 1),
#   (35, 1),
#   (38, 1),
#   (59, 1),
#   (61, 3),
#   (74, 2),
#   (112, 1),
#   (113, 1),
#   (121, 1),
#   (137, 1),
#   (141, 1),
#   (162, 1),
#   (165, 1),
#   (176, 1),
#   (186, 1),
#   (213, 1),
#   (219, 2),
#   (237, 1),
#   (277, 1),
#   (308, 1),
#   (322, 1),
#   (328, 4),
#   (333, 1),
#   (359, 1),
#   (387, 1),
#   (407, 1),
#   (448, 1),
#   (450, 1),
#   (457, 1),
#   (463, 1),
#   (478, 1),
#   (484, 1),
#   (510, 1),
#   (560, 1),
#   (606, 1),
#   (611, 1),
#   (641, 1),
#   (759, 1),
#   (780, 1),
#   (853, 1),
#   (975, 1),
#   (1002, 1),
#   (1043, 1),
#   (1122, 1),
#   (1231, 3),
#   (1339, 1),
#   (1418, 1),
#   (1431, 1),
#   (1498, 1),
#   (1499, 1),
#   (1500, 1),
#   (1501, 1),
#   (1502, 1),
#   (1503, 1),
#   (1504, 1),
#   (1505, 1),
#   (1506, 1),
#   (1507, 1),
#   (1508, 1),
#   (1509, 2)],
#  [(0, 1),
#   (3, 1),
#   (15, 1),
#   (34, 1),
#   (41, 1),
#   (45, 1),
#   (74, 1),
#   (200, 1),
#   (359, 1),
#   (434, 1),
#   (494, 1),
#   (556, 1),
#   (577, 1),
#   (860, 1),
#   (1083, 1),
#   (1510, 1),
#   (1511, 1),
#   (1512, 1),
#   (1513, 1)],
#  [(10, 1),
#   (34, 1),
#   (74, 1),
#   (84, 1),
#   (300, 1),
#   (748, 1),
#   (1117, 1),
#   (1270, 1),
#   (1514, 1)],
#  [(5, 1),
#   (10, 1),
#   (38, 1),
#   (58, 1),
#   (61, 1),
#   (122, 1),
#   (261, 1),
#   (287, 1),
#   (306, 1),
#   (318, 1),
#   (328, 1),
#   (372, 1),
#   (373, 1),
#   (1186, 1)],
#  [(38, 1),
#   (74, 2),
#   (126, 1),
#   (132, 1),
#   (161, 1),
#   (299, 1),
#   (305, 1),
#   (393, 1),
#   (396, 1),
#   (411, 1),
#   (577, 1),
#   (640, 1),
#   (719, 1),
#   (903, 1),
#   (1515, 1)],
#  [(106, 1), (113, 1), (117, 1), (165, 1), (174, 1), (442, 1), (1516, 1)],
#  [(61, 1), (122, 1), (189, 1), (318, 1), (694, 1), (1517, 1)],
#  [(45, 1), (126, 1), (306, 1), (328, 1)],
#  [(1518, 1)],
#  [(214, 1)],
#  [(306, 1)],
#  [(2, 1),
#   (123, 1),
#   (149, 1),
#   (165, 1),
#   (222, 1),
#   (229, 1),
#   (302, 1),
#   (310, 1),
#   (329, 1),
#   (333, 1),
#   (532, 1),
#   (1455, 1),
#   (1519, 1),
#   (1520, 1)],
#  [(1521, 1)],
#  [(5, 1),
#   (34, 1),
#   (38, 3),
#   (61, 2),
#   (74, 1),
#   (163, 1),
#   (176, 1),
#   (287, 1),
#   (302, 1),
#   (328, 1),
#   (372, 1),
#   (373, 1),
#   (756, 1),
#   (1083, 1)],
#  [(5, 1),
#   (113, 1),
#   (163, 1),
#   (165, 1),
#   (175, 1),
#   (318, 1),
#   (1522, 1),
#   (1523, 1)],
#  [(1521, 1)],
#  [(2, 1),
#   (45, 1),
#   (530, 1),
#   (693, 1),
#   (697, 1),
#   (1524, 1),
#   (1525, 1),
#   (1526, 1)],
#  [(38, 1), (61, 1), (248, 1), (436, 1)],
#  [(1527, 1)],
#  [(45, 1), (61, 1), (76, 1), (163, 1), (174, 1), (628, 1)],
#  [(38, 1), (61, 1), (328, 1)],
#  [(34, 1),
#   (41, 1),
#   (61, 1),
#   (126, 1),
#   (277, 1),
#   (306, 1),
#   (549, 1),
#   (1528, 1)],
#  [(34, 1),
#   (61, 1),
#   (79, 1),
#   (147, 1),
#   (174, 1),
#   (287, 1),
#   (328, 1),
#   (556, 1),
#   (615, 1),
#   (1529, 1)],
#  [(2, 1),
# ...
#  [(8, 1),
#   (45, 1),
#   (151, 1),
#   (165, 1),
#   (287, 1),
#   (532, 1),
#   (2157, 1),
#   (2413, 1),
#   (2414, 1)],
#  [(28, 1), (38, 1), (76, 1), (165, 1), (174, 1), (617, 1), (628, 1), (650, 1)],
#  [(523, 1), (719, 1)],
#  [(24, 1),
#   (61, 2),
#   (79, 1),
#   (104, 1),
#   (176, 1),
#   (311, 1),
#   (482, 1),
#   (487, 1),
#   (496, 2),
#   (600, 1),
#   (708, 1),
#   (743, 3),
#   (1094, 3),
#   (1116, 2),
#   (2415, 1),
#   (2416, 1),
#   (2417, 1)],
#  [(132, 1), (174, 1), (322, 1), (494, 1)],
#  [(45, 1),
#   (61, 1),
#   (74, 1),
#   (328, 1),
#   (436, 1),
#   (454, 1),
#   (489, 1),
#   (676, 1),
#   (2418, 1)],
#  [(329, 1)],
#  [(126, 1), (189, 1), (272, 1), (306, 1), (2419, 1)],
#  [(27, 1),
#   (44, 1),
#   (58, 1),
#   (59, 2),
#   (61, 2),
#   (75, 2),
#   (95, 1),
#   (122, 1),
#   (333, 2),
#   (421, 2),
#   (469, 1),
#   (523, 1),
#   (706, 1),
#   (765, 1),
#   (838, 1),
#   (1115, 1),
#   (1281, 1),
#   (2420, 1),
#   (2421, 1)],
#  [(306, 1), (2422, 1)],
#  [(282, 1), (287, 1), (312, 1), (383, 1), (479, 1), (641, 1), (1554, 1)],
#  [(1090, 1)],
#  [(185, 1), (306, 1), (627, 1), (747, 1)],
#  [(227, 1)],
#  [(38, 1), (61, 1), (132, 1), (165, 1), (306, 1), (466, 1), (505, 1)],
#  [(3, 1),
#   (24, 1),
#   (58, 1),
#   (132, 1),
#   (151, 1),
#   (170, 1),
#   (194, 1),
#   (272, 1),
#   (577, 1)],
#  [(44, 1),
#   (61, 1),
#   (95, 1),
#   (133, 1),
#   (151, 1),
#   (165, 1),
#   (370, 1),
#   (412, 1),
#   (494, 1),
#   (900, 1),
#   (933, 1),
#   (978, 1),
#   (1086, 1),
#   (1432, 1),
#   (1455, 1),
#   (1556, 1),
#   (2423, 1)],
#  [(61, 1), (123, 1), (328, 1), (494, 1)],
#  [(61, 2), (374, 1), (494, 1), (615, 1), (1387, 1)],
#  [(8, 2),
#   (55, 1),
#   (61, 1),
#   (76, 1),
#   (165, 1),
#   (220, 1),
#   (274, 1),
#   (287, 1),
#   (306, 3),
#   (308, 1),
#   (312, 3),
#   (324, 1),
#   (425, 1),
#   (489, 1),
#   (532, 2),
#   (609, 1),
#   (611, 2),
#   (1077, 1),
#   (1443, 1),
#   (2424, 1),
#   (2425, 1),
#   (2426, 1),
#   (2427, 1)],
#  [(1521, 1)],
#  [(38, 1),
#   (43, 1),
#   (61, 1),
#   (74, 1),
#   (133, 1),
#   (325, 2),
#   (328, 1),
#   (333, 1),
#   (483, 1),
#   (924, 1),
#   (953, 1),
#   (1115, 1),
#   (1766, 1)],
#  [(38, 1), (1915, 1)],
#  [(10, 1),
#   (74, 1),
#   (121, 1),
#   (133, 1),
#   (142, 1),
#   (207, 1),
#   (304, 1),
#   (355, 1),
#   (425, 1),
#   (522, 1),
#   (530, 1),
#   (1135, 1),
#   (2428, 1),
#   (2429, 1),
#   (2430, 1),
#   (2431, 1)],
#  [(10, 1), (306, 1), (312, 1), (897, 1)],
#  [(329, 1)],
#  [(61, 1), (185, 1), (494, 1), (1414, 2)],
#  [(0, 1),
#   (5, 3),
#   (10, 7),
#   (15, 1),
#   (34, 1),
#   (35, 2),
#   (37, 1),
#   (39, 1),
#   (42, 2),
#   (58, 1),
#   (61, 4),
#   (74, 9),
#   (75, 3),
#   (81, 2),
#   (95, 2),
#   (98, 1),
#   (99, 2),
#   (103, 1),
#   (131, 1),
#   (137, 1),
#   (146, 2),
#   (162, 1),
#   (175, 2),
#   (177, 1),
#   (185, 1),
#   (188, 1),
#   (196, 2),
#   (216, 1),
#   (219, 1),
#   (243, 2),
#   (258, 1),
#   (277, 1),
#   (287, 4),
#   (302, 1),
#   (305, 2),
#   (307, 1),
#   (312, 5),
#   (318, 1),
#   (328, 1),
#   (331, 1),
#   (338, 1),
#   (369, 1),
#   (373, 2),
#   (378, 2),
#   (383, 1),
#   (396, 1),
#   (425, 1),
#   (427, 1),
#   (434, 1),
#   (436, 1),
#   (450, 3),
#   (457, 1),
#   (478, 1),
#   (506, 2),
#   (558, 1),
#   (572, 1),
#   (629, 1),
#   (632, 3),
#   (645, 1),
#   (650, 1),
#   (691, 1),
#   (693, 1),
#   (694, 1),
#   (729, 1),
#   (785, 1),
#   (924, 1),
#   (1004, 1),
#   (1026, 1),
#   (1061, 1),
#   (1123, 1),
#   (1143, 1),
#   (1148, 2),
#   (1152, 1),
#   (1158, 1),
#   (1231, 8),
#   (1313, 2),
#   (1314, 2),
#   (1388, 1),
#   (1418, 1),
#   (1431, 1),
#   (1496, 2),
#   (1513, 2),
#   (1603, 1),
#   (1640, 2),
#   (1685, 2),
#   (1703, 1),
#   (1763, 1),
#   (1792, 1),
#   (1867, 1),
#   (1950, 3),
#   (2074, 1),
#   (2085, 1),
#   (2253, 1),
#   (2258, 1),
#   (2360, 1),
#   (2432, 1),
#   (2433, 1),
#   (2434, 1),
#   (2435, 1),
#   (2436, 1),
#   (2437, 1),
#   (2438, 1),
#   (2439, 1),
#   (2440, 1),
#   (2441, 1),
#   (2442, 1),
#   (2443, 1),
#   (2444, 1),
#   (2445, 1),
#   (2446, 1),
#   (2447, 1),
#   (2448, 1),
#   (2449, 1),
#   (2450, 1),
#   (2451, 1),
#   (2452, 2),
#   (2453, 1),
#   (2454, 1),
#   (2455, 1),
#   (2456, 1),
#   (2457, 1),
#   (2458, 1),
#   (2459, 1),
#   (2460, 1),
#   (2461, 1),
#   (2462, 1),
#   (2463, 1),
#   (2464, 1),
#   (2465, 1),
#   (2466, 2),
#   (2467, 1),
#   (2468, 2),
#   (2469, 1),
#   (2470, 1)],
#  [(10, 1),
#   (11, 1),
#   (27, 1),
#   (40, 1),
#   (41, 2),
#   (54, 1),
#   (61, 7),
#   (92, 1),
#   (103, 1),
#   (122, 1),
#   (131, 1),
#   (132, 2),
#   (148, 1),
#   (162, 1),
#   (165, 3),
#   (172, 1),
#   (259, 1),
#   (302, 1),
#   (304, 1),
#   (310, 1),
#   (318, 4),
#   (390, 1),
#   (429, 1),
#   (450, 1),
#   (483, 1),
#   (494, 3),
#   (621, 1),
#   (678, 1),
#   (729, 1),
#   (959, 1),
#   (1102, 1),
#   (1160, 1),
#   (1755, 1),
#   (2008, 1),
#   (2088, 1),
#   (2471, 1),
#   (2472, 1)],
#  [(5, 1), (61, 1), (318, 1), (494, 1), (628, 1), (1426, 1), (2473, 1)],
#  [(54, 1),
#   (58, 2),
#   (61, 2),
#   (121, 1),
#   (122, 1),
#   (145, 1),
#   (149, 1),
#   (333, 1),
#   (354, 1),
#   (560, 2),
#   (721, 1),
#   (1414, 1)],
#  [(61, 1), (523, 1)],
#  [(58, 1),
#   (370, 1),
#   (474, 2),
#   (478, 1),
#   (533, 1),
#   (563, 1),
#   (697, 2),
#   (2474, 1),
#   (2475, 1),
#   (2476, 1)],
#  [(10, 1),
#   (306, 2),
#   (331, 1),
#   (395, 1),
#   (523, 1),
#   (698, 1),
#   (719, 1),
#   (756, 1)],
#  [(1521, 1)],
#  [(306, 1)],
#  [(45, 1), (122, 1), (310, 1), (328, 1), (362, 1), (1308, 1), (2477, 1)],
#  [(884, 1)],
#  [(61, 1), (328, 1)],
#  [(61, 2),
#   (113, 1),
#   (132, 1),
#   (151, 1),
#   (187, 1),
#   (319, 1),
#   (347, 1),
#   (496, 1),
#   (606, 1),
#   (810, 1),
#   (1508, 1),
#   (2478, 1)],
#  [(228, 1), (893, 1)],
#  [(61, 1),
#   (151, 1),
#   (328, 1),
#   (436, 1),
#   (658, 1),
#   (2479, 1),
#   (2480, 1),
#   (2481, 1)],
#  [(1645, 1), (2482, 1)],
#  [(8, 1),
#   (24, 1),
#   (45, 1),
#   (58, 1),
#   (61, 1),
#   (66, 1),
#   (103, 1),
#   (184, 1),
#   (253, 1),
#   (289, 1),
#   (311, 1),
#   (325, 1),
#   (366, 1),
#   (489, 1),
#   (607, 1),
#   (669, 1),
#   (675, 1),
#   (719, 1),
#   (891, 1),
#   (1069, 1),
#   (1313, 1),
#   (1607, 1),
#   (2483, 2)],
#  [(10, 1),
#   (77, 1),
#   (126, 1),
#   (302, 1),
#   (306, 1),
#   (618, 1),
#   (698, 1),
#   (845, 1),
#   (999, 1),
#   (1233, 1),
#   (1523, 1),
#   (2484, 1),
#   (2485, 1)],
#  [(2486, 1)],
#  [(8, 1),
#   (44, 2),
#   (61, 1),
#   (95, 3),
#   (113, 1),
#   (204, 1),
#   (207, 1),
#   (301, 1),
#   (316, 1),
#   (396, 1),
#   (411, 1),
#   (427, 1),
#   (434, 1),
#   (450, 1),
#   (489, 1),
#   (496, 1),
#   (513, 1),
#   (577, 1),
#   (585, 1),
#   (990, 1),
#   (2044, 1),
#   (2461, 1),
#   (2487, 1),
#   (2488, 1)],
#  [(2489, 1)],
#  [(306, 1), (2490, 1)],
#  [(98, 1)],
#  [(61, 1), (436, 1), (1231, 1), (2422, 1), (2491, 1), (2492, 1), (2493, 1)],
#  [(105, 1), (1931, 1)],
#  [(434, 1), (474, 1), (477, 1), (1922, 1), (2494, 1)],
#  [(92, 1),
#   (308, 1),
#   (311, 2),
#   (318, 1),
#   (406, 1),
#   (427, 1),
#   (467, 1),
#   (529, 1),
#   (832, 1),
#   (834, 1),
#   (2495, 1),
#   (2496, 1)],
#  [(28, 1),
#   (163, 1),
#   (357, 1),
#   (898, 1),
#   (1022, 1),
#   (1083, 1),
#   (1532, 1),
#   (2497, 1)],
#  [(38, 1), (165, 1), (188, 1), (259, 1), (322, 1), (453, 1), (2180, 1)],
#  [(306, 1)],
#  [(306, 1)],
#  [(974, 1), (976, 1)],
#  [(302, 1), (306, 1), (959, 1)],
#  [(328, 1), (2498, 1), (2499, 1)],
#  [(28, 1), (45, 1), (328, 1), (329, 1)],
#  [(38, 1), (126, 1), (719, 1)],
#  [(1890, 1), (2500, 1), (2501, 1)],
#  [(38, 1), (61, 1), (618, 1), (832, 1)],
#  [(61, 1), (306, 1)],
#  [(306, 1), (453, 1)],
#  [(1090, 1)],
#  [(1090, 1)],
#  [(523, 1)],
#  [(1090, 1)],
#  [(2502, 1)],
#  [(126, 1), (1732, 1)],
#  [(884, 1)],
#  [],
#  [(311, 1), (719, 1)],
#  [(165, 1), (676, 1)],
#  [(28, 1), (884, 1)],
#  [(61, 1), (523, 1)],
#  [(61, 1), (494, 1)],
#  [(494, 1)],
#  [(2503, 1)],
#  [(2504, 1)],
#  [(61, 1),
#   (79, 1),
#   (165, 1),
#   (270, 1),
#   (292, 1),
#   (421, 1),
#   (437, 1),
#   (496, 1),
#   (703, 1),
#   (2505, 1),
#   (2506, 1),
#   (2507, 1)],
#  [(8, 1),
#   (14, 1),
#   (32, 1),
#   (34, 1),
#   (43, 1),
#   (56, 1),
#   (61, 1),
#   (74, 2),
#   (132, 2),
#   (137, 1),
#   (162, 1),
#   (165, 1),
#   (213, 1),
#   (215, 1),
#   (287, 1),
#   (339, 1),
#   (362, 1),
#   (428, 1),
#   (442, 1),
#   (469, 1),
#   (501, 1),
#   (581, 1),
#   (786, 1),
#   (828, 1),
#   (916, 1),
#   (2508, 1),
#   (2509, 1)],
#  [(3, 3),
#   (9, 1),
#   (27, 2),
#   (32, 1),
#   (35, 1),
#   (56, 1),
#   (61, 2),
#   (75, 1),
#   (79, 1),
#   (101, 1),
#   (111, 2),
#   (116, 1),
#   (121, 2),
#   (137, 2),
#   (145, 1),
#   (148, 1),
#   (149, 1),
#   (176, 1),
#   (194, 1),
#   (204, 1),
#   (245, 1),
#   (268, 1),
#   (272, 1),
#   (276, 1),
#   (339, 1),
#   (357, 1),
#   (421, 1),
#   (448, 1),
#   (453, 1),
#   (470, 1),
#   (496, 1),
#   (529, 1),
#   (534, 1),
#   (572, 1),
#   (651, 1),
#   (654, 1),
#   (698, 1),
#   (707, 1),
#   (773, 1),
#   (791, 1),
#   (820, 1),
#   (845, 1),
#   (851, 1),
#   (853, 1),
#   (1062, 1),
#   (1184, 1),
#   (1654, 1),
#   (1703, 1),
#   (1778, 1),
#   (1883, 1),
#   (2101, 1),
#   (2223, 1),
#   (2227, 1),
#   (2423, 1),
#   (2428, 1),
#   (2510, 1),
#   (2511, 1),
#   (2512, 1),
#   (2513, 1),
#   (2514, 1),
#   (2515, 1),
#   (2516, 1),
#   (2517, 1),
#   (2518, 1),
#   (2519, 1)],
#  [(61, 1),
#   (130, 1),
#   (132, 1),
#   (174, 1),
#   (182, 1),
#   (210, 1),
#   (442, 1),
#   (786, 1),
#   (2222, 1)],
#  [(5, 1),
#   (36, 1),
#   (44, 1),
#   (47, 1),
#   (59, 2),
#   (75, 2),
#   (111, 1),
#   (151, 1),
#   (165, 1),
#   (187, 1),
#   (219, 1),
#   (301, 1),
#   (302, 1),
#   (316, 2),
#   (323, 2),
#   (453, 2),
#   (496, 1),
#   (530, 2),
#   (628, 1),
#   (731, 3),
#   (768, 1),
#   (999, 1),
#   (1017, 1),
#   (1033, 1),
#   (1128, 1),
#   (1200, 1),
#   (1284, 1),
#   (1516, 1),
#   (1580, 2),
#   (1863, 1),
#   (1928, 1),
#   (2044, 1),
#   (2520, 1),
#   (2521, 1),
#   (2522, 1),
#   (2523, 1),
#   (2524, 1)],
#  [(1, 1),
#   (8, 1),
#   (28, 1),
#   (61, 1),
#   (75, 1),
#   (101, 1),
#   (113, 1),
#   (173, 1),
#   (187, 1),
#   (221, 1),
#   (236, 1),
#   (330, 1),
#   (419, 1),
#   (442, 1),
#   (474, 1),
#   (506, 2),
#   (507, 1),
#   (641, 1),
#   (880, 1),
#   (1194, 1),
#   (1486, 1),
#   (1513, 1),
#   (1589, 1),
#   (1802, 1),
#   (2525, 1),
#   (2526, 1)],
#  [(11, 1),
#   (19, 1),
#   (24, 1),
#   (55, 1),
#   (61, 2),
#   (75, 2),
#   (77, 2),
#   (79, 1),
#   (116, 1),
#   (148, 1),
#   (160, 1),
#   (163, 1),
#   (180, 1),
#   (194, 1),
#   (230, 2),
#   (238, 1),
#   (277, 1),
#   (321, 1),
#   (323, 1),
#   (334, 1),
#   (354, 1),
#   (453, 1),
#   (577, 1),
#   (651, 1),
#   (669, 2),
#   (694, 1),
#   (732, 1),
#   (791, 2),
#   (794, 1),
#   (855, 1),
#   (891, 1),
#   (948, 1),
#   (1152, 1),
#   (1230, 3),
#   (1286, 1),
#   (1334, 1),
#   (1607, 1),
#   (1936, 1),
#   (2032, 1),
#   (2380, 1),
#   (2401, 1),
#   (2478, 1),
#   (2527, 1),
#   (2528, 2),
#   (2529, 1),
#   (2530, 2),
#   (2531, 1),
#   (2532, 1),
#   (2533, 1),
#   (2534, 1),
#   (2535, 1),
#   (2536, 1),
#   (2537, 1),
#   (2538, 1),
#   (2539, 1),
#   (2540, 1)],
#  [(8, 1),
#   (38, 1),
#   (61, 2),
#   (104, 1),
#   (126, 1),
#   (165, 1),
#   (209, 1),
#   (282, 1),
#   (287, 1),
#   (289, 2),
#   (295, 1),
#   (302, 1),
#   (311, 1),
#   (318, 1),
#   (577, 1),
#   (1928, 1),
#   (2541, 1)],
#  [(0, 1),
#   (8, 1),
#   (61, 3),
#   (169, 1),
#   (412, 1),
#   (433, 1),
#   (898, 1),
#   (1435, 1),
#   (2542, 1),
#   (2543, 1)],
#  [(45, 1),
#   (113, 1),
#   (160, 1),
#   (175, 1),
#   (292, 1),
#   (318, 1),
#   (322, 1),
#   (333, 1),
#   (501, 1),
#   (606, 1),
#   (2544, 1),
#   (2545, 1)],
#  [(27, 1),
#   (32, 1),
#   (59, 1),
#   (61, 2),
#   (75, 1),
#   (77, 1),
#   (102, 1),
#   (139, 1),
#   (168, 1),
#   (175, 1),
#   (222, 1),
#   (236, 1),
#   (250, 1),
#   (287, 1),
#   (311, 2),
#   (334, 1),
#   (347, 1),
#   (361, 1),
#   (378, 1),
#   (457, 1),
#   (468, 1),
#   (483, 1),
#   (525, 1),
#   (565, 1),
#   (699, 1),
#   (1366, 1),
#   (1469, 1),
#   (1741, 1),
#   (1875, 1),
#   (2222, 2),
#   (2546, 1),
#   (2547, 1),
#   (2548, 1),
#   (2549, 1),
#   (2550, 1),
#   (2551, 1),
#   (2552, 1),
#   (2553, 1),
#   (2554, 1),
#   (2555, 2)],
#  [(8, 1),
#   (28, 1),
#   (58, 1),
#   (61, 1),
#   (65, 1),
#   (147, 1),
#   (236, 1),
#   (272, 1),
#   (311, 1),
#   (319, 1),
#   (359, 1),
#   (375, 1),
#   (532, 1),
#   (607, 2),
#   (822, 1),
#   (2380, 1)],
#  [(523, 1)],
#  [(207, 1)],
#  [(29, 1),
#   (45, 1),
#   (61, 1),
#   (79, 1),
#   (95, 1),
#   (107, 1),
#   (113, 1),
#   (165, 2),
#   (277, 1),
#   (288, 1),
#   (292, 1),
#   (333, 1),
#   (374, 2),
#   (382, 2),
#   (429, 1),
#   (496, 2),
#   (514, 1),
#   (617, 1),
#   (638, 1),
#   (665, 1),
#   (667, 1),
#   (706, 1),
#   (707, 1),
#   (786, 2),
#   (1580, 1),
#   (1742, 1),
#   (2556, 1),
#   (2557, 1),
#   (2558, 1),
#   (2559, 1)],
#  [(137, 1),
#   (287, 1),
#   (307, 1),
#   (436, 1),
#   (457, 1),
#   (486, 1),
#   (845, 1),
#   (943, 1),
#   (2560, 1),
#   (2561, 1),
#   (2562, 1)],
#  [(103, 1), (288, 1), (425, 1), (626, 1), (810, 1)],
#  [(10, 1),
#   (11, 1),
#   (28, 1),
#   (38, 1),
#   (61, 3),
#   (84, 1),
#   (104, 1),
#   (270, 1),
#   (307, 1),
#   (316, 1),
#   (437, 1),
#   (467, 1),
#   (834, 1),
#   (858, 1),
#   (901, 1),
#   (1158, 1),
#   (1160, 1),
#   (1590, 1),
#   (1735, 1),
#   (1736, 1),
#   (1817, 1),
#   (2218, 1),
#   (2563, 1),
#   (2564, 1),
#   (2565, 1)],
#  [(6, 1),
#   (27, 2),
#   (32, 1),
#   (54, 2),
#   (61, 2),
#   (132, 1),
#   (137, 1),
#   (318, 1),
#   (329, 1),
#   (372, 1),
#   (438, 1),
#   (496, 1),
#   (502, 1),
#   (521, 1),
#   (522, 1),
#   (530, 1),
#   (560, 1),
#   (563, 1),
#   (565, 1),
#   (577, 1),
#   (691, 1),
#   (814, 1),
#   (828, 1),
#   (905, 1),
#   (1545, 1),
#   (1853, 1),
#   (2566, 1),
#   (2567, 1),
#   (2568, 1),
#   (2569, 1),
#   (2570, 1)],
#  [(61, 1), (113, 1), (172, 1), (175, 1), (951, 1), (1296, 1), (2416, 1)],
#  [(669, 1), (924, 1)],
#  [(2571, 1)],
#  [(38, 1), (41, 1), (258, 1), (428, 1), (467, 1)],
#  [(38, 1), (943, 1)],
#  [(61, 1), (523, 1)],
#  [(61, 1),
#   (192, 1),
#   (227, 1),
#   (307, 1),
#   (354, 1),
#   (1154, 1),
#   (1754, 1),
#   (2572, 1)],
#  [(523, 1)],
#  [(11, 1),
#   (41, 1),
#   (78, 1),
#   (122, 1),
#   (142, 1),
#   (214, 1),
#   (305, 3),
#   (306, 1),
#   (307, 1),
#   (400, 2),
#   (496, 1),
#   (557, 1),
#   (659, 1),
#   (669, 1),
#   (883, 1),
#   (1432, 1),
#   (1435, 1),
#   (1956, 1),
#   (2461, 1),
#   (2573, 1),
#   (2574, 1),
#   (2575, 1)],
#  [(1084, 1), (2181, 1)],
#  [(236, 1), (575, 1), (579, 1), (743, 1), (884, 1), (1747, 1)],
#  [(38, 1), (61, 1), (98, 1), (236, 1), (457, 1), (1577, 1), (2576, 1)],
#  [(2180, 1)],
#  [(494, 1)],
#  [(61, 1), (436, 1)],
#  [(44, 1),
#   (113, 1),
#   (165, 1),
#   (270, 2),
#   (322, 1),
#   (453, 1),
#   (467, 1),
#   (496, 3),
#   (593, 1),
#   (2577, 1),
#   (2578, 1)],
#  [(8, 1),
#   (34, 1),
#   (35, 1),
#   (74, 1),
#   (75, 1),
#   (194, 1),
#   (477, 1),
#   (533, 1),
#   (693, 1),
#   (851, 1),
#   (1748, 1),
#   (1875, 1),
#   (2543, 1),
#   (2579, 1)],
#  [(307, 1), (453, 1), (489, 1), (706, 1)],
#  [(41, 1),
#   (61, 1),
#   (77, 1),
#   (126, 1),
#   (340, 1),
#   (369, 1),
#   (410, 1),
#   (957, 1),
#   (1444, 1),
#   (1736, 1),
#   (1897, 1),
#   (2580, 1),
#   (2581, 1)],
#  [(32, 1),
#   (54, 1),
#   (75, 1),
#   (77, 1),
#   (103, 1),
#   (172, 1),
#   (230, 1),
#   (329, 1),
#   (333, 1),
#   (467, 1),
#   (519, 1),
#   (609, 1),
#   (719, 1),
#   (767, 1),
#   (834, 1),
#   (1072, 1),
#   (1741, 1)],
#  [(174, 1), (1066, 1), (2494, 1)],
#  [(61, 2),
#   (132, 1),
#   (168, 1),
#   (182, 1),
#   (215, 1),
#   (334, 1),
#   (572, 2),
#   (719, 1),
#   (791, 1),
#   (973, 1),
#   (1493, 1),
#   (2582, 1)],
#  [(307, 1), (700, 1), (2583, 1)],
#  [(0, 1),
#   (29, 1),
#   (34, 1),
#   (35, 1),
#   (37, 2),
#   (44, 2),
#   (45, 1),
#   (49, 1),
#   (52, 2),
#   (61, 5),
#   (74, 1),
#   (75, 1),
#   (83, 1),
#   (92, 1),
#   (112, 1),
#   (113, 1),
#   (121, 1),
#   (122, 1),
#   (126, 1),
#   (175, 3),
#   (213, 1),
#   (221, 1),
#   (245, 1),
#   (272, 1),
#   (311, 1),
#   (319, 2),
#   (322, 1),
#   (325, 1),
#   (333, 1),
#   (360, 1),
#   (393, 1),
#   (406, 1),
#   (429, 1),
#   (457, 4),
#   (474, 1),
#   (480, 1),
#   (483, 1),
#   (489, 1),
#   (494, 1),
#   (496, 1),
#   (506, 1),
#   (509, 2),
#   (523, 1),
#   (548, 1),
#   (569, 1),
#   (651, 1),
#   (735, 2),
#   (743, 1),
#   (756, 1),
#   (805, 1),
#   (832, 1),
#   (928, 1),
#   (973, 1),
#   (1425, 1),
#   (1453, 1),
#   (1469, 1),
#   (1513, 2),
#   (1664, 1),
#   (1782, 1),
#   (2051, 1),
#   (2076, 2),
#   (2380, 1),
#   (2417, 1),
#   (2584, 1),
#   (2585, 1),
#   (2586, 2),
#   (2587, 1),
#   (2588, 1),
#   (2589, 1),
#   (2590, 1)],
#  [(11, 1),
#   (43, 1),
#   (44, 1),
#   (61, 1),
#   (103, 1),
#   (113, 3),
#   (175, 2),
#   (322, 1),
#   (333, 2),
#   (412, 1),
#   (470, 1),
#   (513, 2),
#   (638, 1),
#   (675, 1),
#   (719, 2),
#   (761, 1),
#   (845, 2),
#   (893, 1),
#   (999, 1),
#   (1056, 1),
#   (1398, 1),
#   (1435, 1),
#   (2052, 1),
#   (2223, 1),
#   (2591, 1)],
#  [(5, 1),
#   (38, 1),
#   (45, 1),
#   (54, 1),
#   (61, 1),
#   (126, 1),
#   (133, 1),
#   (165, 1),
#   (233, 1),
#   (306, 1),
#   (334, 1),
#   (442, 1),
#   (863, 1),
#   (938, 1),
#   (1023, 1),
#   (1341, 1),
#   (1342, 1),
#   (1879, 1),
#   (1902, 1)],
#  [(14, 1),
#   (27, 1),
#   (28, 1),
#   (61, 2),
#   (75, 1),
#   (84, 1),
#   (88, 1),
#   (92, 1),
#   (95, 1),
#   (116, 1),
#   (139, 1),
#   (147, 1),
#   (152, 1),
#   (165, 1),
#   (182, 1),
#   (276, 1),
#   (304, 1),
#   (307, 1),
#   (310, 1),
#   (374, 1),
#   (422, 1),
#   (450, 1),
#   (467, 1),
#   (470, 1),
#   (473, 1),
#   (501, 1),
#   (707, 1),
#   (766, 1),
#   (768, 1),
#   (832, 1),
#   (909, 1),
#   (1006, 1),
#   (1200, 1),
#   (1762, 1),
#   (1863, 1),
#   (2313, 1),
#   (2592, 1),
#   (2593, 1),
#   (2594, 1),
#   (2595, 1),
#   (2596, 1),
#   (2597, 1),
#   (2598, 1),
#   (2599, 1),
#   (2600, 1)]]
